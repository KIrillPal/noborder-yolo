# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Load config
import json
import numpy as np
from pathlib import Path
from matplotlib import pyplot as plt

import sys
sys.path.append('../../../utils')
sys.path.append('../../..')

# %%
IMAGE_SHAPE = (1000, 1000)
CONFIG_PATH = '../../../config.json'
SPLIT = 'test'
IOU_THRESHOLD = 0.7

# %% [markdown]
# ### Создадим агрегатор

# %%
from src.aggregate.base import Aggregator, ComposeClassifier
from src.aggregate.threshold import ThresholdClassifier
from src.aggregate.noborder import NoBorderClassifier
from src.aggregate.confidence import ConfidenceClassifier
from src.aggregate.merge import UnionMerger

# %%
N_CLASSES = 2
INTEGRATE_THRESHOLD = 1

# %%
classifier = ThresholdClassifier(N_CLASSES, INTEGRATE_THRESHOLD)
merger = UnionMerger(N_CLASSES)
gt_aggregator = Aggregator(classifier, merger)

# %% [markdown]
# ### Интерполированный тест

# %%
import pickle
import json
TEST_NAME = 'dense'
with open(f'../../../groups/gt_test_{TEST_NAME}.pkl', 'rb') as f:
    gt_extended_groups = pickle.load(f)
with open(f'../../../groups/pred_test_{TEST_NAME}.pkl', 'rb') as f:
    pred_extended_groups = pickle.load(f)
with open(f'../../../data/{TEST_NAME}_test/speed.json') as f:
    speed_dict = json.load(f)
    shifts = {}
    speed_sum = 0
    for k, v in sorted(speed_dict.items(), key=lambda x: x[0]):
        speed_sum += v
        shifts[Path(k).name] = speed_sum

# %%
plt.hist([len(g) for g in gt_extended_groups], bins=50)
median_length = int(np.median([len(g) for g in pred_extended_groups]))
print(f"Median group size: {median_length}")
# Out:
# Median group size: 13

# %% [markdown]
# ### Получим группы на ленте

# %%
from copy import deepcopy
import random
from utils.integrate.integrate import shift_mask
from utils.interpolate.refine_markup_by_yolo import poly, mask_iou, get_box

def align_group(ext_group, shifts):
    ext_group = deepcopy(ext_group)
    for obj in ext_group:
        shift = shifts[obj['img'].name]
        conf = None
        if 'conf' in obj['obj']:
            conf = float(obj['obj']['conf'])
        obj['obj'] = shift_mask(obj['obj'], shift)
        obj['obj']['is_border'] = obj['is_border']
        if conf is not None:
            obj['obj']['conf'] = conf
    return ext_group

def align_groups(ext_group, shifts):
    return [
        align_group(ext_group, shifts)
        for ext_group in ext_group
    ]

# %%
gt_aligned_groups = align_groups(gt_extended_groups, shifts)
pred_aligned_groups = align_groups(pred_extended_groups, shifts)

# %%
gt_groups = [[o['obj'] for o in g] for g in gt_aligned_groups]
pred_groups = [[o['obj'] for o in g]  for g in pred_aligned_groups]

# %%
for polygon in map(poly, gt_groups[random.randint(0, len(gt_groups))]):
    x, y = polygon.exterior.xy
    plt.plot(x, y)
plt.show()

# %% [markdown]
# ### Метрики

# %%
from tqdm import tqdm 

def boxes_intersect(box1, box2):
    x1, y1, w1, h1 = box1
    x2, y2, w2, h2 = box2
    
    # Check if one box is to the right of the other
    if x1 + w1 <= x2 or x2 + w2 <= x1:
        return False
        
    # Check if one box is above the other
    if y1 + h1 <= y2 or y2 + h2 <= y1:
        return False
        
    return True

def find_matches(gt : list[dict], pred : list[dict], iou_threshold : float = 0.7):
    gt_boxes = [get_box(t) for t in gt]
    pred_boxes = [get_box(t) for t in pred]

    gt_matches = [False] * len(gt)
    pred_matches = [False] * len(pred)

    for i, gt_obj in tqdm(enumerate(gt), total=len(gt)):
        for j, pred_obj in enumerate(pred):
            if boxes_intersect(gt_boxes[i], pred_boxes[j]):
                iou = mask_iou(gt_obj, pred_obj)
                if iou > iou_threshold:
                    gt_matches[i] = True
                    pred_matches[j] = True
    return np.array(gt_matches), np.array(pred_matches)

# %% [markdown]
# ### Оптимальный агрегатор

# %%
def find_best_aggregator(gt):
    thresholds = list(range(1, 10))
    confidences = np.linspace(0.35, 0.9, 12)
    remove_border_options = [False, True]
    precisions = np.zeros((len(remove_border_options), len(thresholds), len(confidences)))
    recalls    = np.zeros((len(remove_border_options), len(thresholds), len(confidences)))
    f1_scores  = np.zeros((len(remove_border_options), len(thresholds), len(confidences)))

    for i, remove_borders in enumerate(remove_border_options):
        for j, integration_threshold in enumerate(thresholds):
            for k, confidence_threshold in enumerate(confidences):
                compose_list = []
                if remove_borders:
                    compose_list.append(NoBorderClassifier(N_CLASSES, IMAGE_SHAPE))
                compose_list.append(ConfidenceClassifier(N_CLASSES, confidence_threshold))
                compose_list.append(ThresholdClassifier(N_CLASSES, integration_threshold))
                classifier = ComposeClassifier(compose_list)
                merger = UnionMerger(N_CLASSES)
                aggregator = Aggregator(classifier, merger)
                
                pred = aggregator.aggregate(pred_groups)
                gt_matches, pred_matches = find_matches(gt, pred)

                precision = np.mean(pred_matches) if len(pred_matches) > 0 else 0
                recall = np.mean(gt_matches) if len(gt_matches) > 0 else 0
                f1 = 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0

                precisions[i, j, k] = precision
                recalls[i, j, k] = recall
                f1_scores[i, j, k] = f1

                print(f"No border: {remove_borders}, Integration: {integration_threshold}, Confidence: {confidence_threshold}. F1: {f1}")

    return precisions, recalls, f1_scores

# %%
gt = gt_aggregator.aggregate(gt_groups)
precisions, recalls, f1_scores = find_best_aggregator(gt)
# Out:
# 100%|██████████| 792/792 [00:40<00:00, 19.51it/s]
# No border: False, Integration: 1, Confidence: 0.5. F1: 0.8693906483642139
# 100%|██████████| 792/792 [00:39<00:00, 19.92it/s]
# No border: False, Integration: 1, Confidence: 0.55. F1: 0.8770569470326269
# 100%|██████████| 792/792 [00:37<00:00, 20.86it/s]
# No border: False, Integration: 1, Confidence: 0.6. F1: 0.8807249890177831
# 100%|██████████| 792/792 [00:36<00:00, 21.67it/s]
# No border: False, Integration: 1, Confidence: 0.65. F1: 0.8871105229868151
# 100%|██████████| 792/792 [00:34<00:00, 23.12it/s]
# No border: False, Integration: 1, Confidence: 0.7. F1: 0.8765805154539289
# 100%|██████████| 792/792 [00:33<00:00, 23.65it/s]
# No border: False, Integration: 1, Confidence: 0.75. F1: 0.8683623594172639
# 100%|██████████| 792/792 [00:29<00:00, 26.47it/s]
# No border: False, Integration: 1, Confidence: 0.8. F1: 0.8369435848607474
# 100%|██████████| 792/792 [00:25<00:00, 31.43it/s]
# No border: False, Integration: 1, Confidence: 0.8500000000000001. F1: 0.7725182514919269
#  24%|██▍       | 194/792 [00:00<00:03, 155.51it/s]
# WARNING: a mask were corrupted. Skipped
# 100%|██████████| 792/792 [00:10<00:00, 77.94it/s]
# No border: False, Integration: 1, Confidence: 0.9. F1: 0.39956769160635347
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 2
#       1 gt = gt_aggregator.aggregate(gt_groups)
# ----> 2 precisions, recalls, f1_scores = find_best_aggregator(gt)
#       3 with open(f"{TEST_NAME}_precision.pkl", 'wb') as f:
#       4     pickle.dump(precisions, f)
#
# Cell In[14], line 21, in find_best_aggregator(gt)
#      18 merger = UnionMerger(N_CLASSES)
#      19 aggregator = Aggregator(classifier, merger)
# ---> 21 pred = aggregator.aggregate(pred_groups)
#      22 gt_matches, pred_matches = find_matches(gt, pred)
#      24 precision = np.mean(pred_matches) if len(pred_matches) > 0 else 0
#
# File /alpha/projects/wastie/code/kondrashov/delta/notes/aggregate/gridsearch/../../../src/aggregate/base.py:27, in Aggregator.aggregate(self, groups)
#      25 def aggregate(self, groups : list[list[dict]]) -> list[dict]:
#      26     groups, classes = self.classifier_.classify(groups)
# ---> 27     return self.merger_.merge(groups, classes)
#
# File /alpha/projects/wastie/code/kondrashov/delta/notes/aggregate/gridsearch/../../../src/aggregate/merge.py:14, in UnionMerger.merge(self, groups, classes)
#      13 def merge(self, groups : list[list[dict]], classes: list[int]):
# ---> 14     return [{
#      15         "points": self.merge_group_(g, i),
#      16         "cls": c,
#      17         "count": 1,
#      18         "group_id": i
#      19     } for i, (g, c) in enumerate(zip(groups, classes))
#      20     if c != NO_OBJECT]
#
# File /alpha/projects/wastie/code/kondrashov/delta/notes/aggregate/gridsearch/../../../src/aggregate/merge.py:15, in <listcomp>(.0)
#      13 def merge(self, groups : list[list[dict]], classes: list[int]):
#      14     return [{
# ---> 15         "points": self.merge_group_(g, i),
#      16         "cls": c,
#      17         "count": 1,
#      18         "group_id": i
#      19     } for i, (g, c) in enumerate(zip(groups, classes))
#      20     if c != NO_OBJECT]
#
# File /alpha/projects/wastie/code/kondrashov/delta/notes/aggregate/gridsearch/../../../src/aggregate/merge.py:25, in UnionMerger.merge_group_(self, group, group_id)
#      23 def merge_group_(self, group, group_id):
#      24     mask_polygons = [poly(g) for g in group]
# ---> 25     polygon = unary_union(mask_polygons)
#      26     if not isinstance(polygon, Polygon):
#      27         # Get max polygon if there are several
#      28         aviable_polygons = [p for p in polygon.geoms if p.geom_type == 'Polygon']
#
# File /alpha/projects/wastie/code/kondrashov/delta/.venv/lib/python3.10/site-packages/shapely/ops.py:135, in CollectionOperator.unary_union(self, geoms)
#     129 def unary_union(self, geoms):
#     130     """Returns the union of a sequence of geometries
#     131
#     132     Usually used to convert a collection into the smallest set of polygons
#     133     that cover the same area.
#     134     """
# --> 135     return shapely.union_all(geoms, axis=None)
#
# File /alpha/projects/wastie/code/kondrashov/delta/.venv/lib/python3.10/site-packages/shapely/decorators.py:77, in multithreading_enabled.<locals>.wrapped(*args, **kwargs)
#      75     for arr in array_args:
#      76         arr.flags.writeable = False
# ---> 77     return func(*args, **kwargs)
#      78 finally:
#      79     for arr, old_flag in zip(array_args, old_flags):
#
# File /alpha/projects/wastie/code/kondrashov/delta/.venv/lib/python3.10/site-packages/shapely/set_operations.py:421, in union_all(geometries, grid_size, axis, **kwargs)
#     417         raise ValueError("grid_size parameter only accepts scalar values")
#     419     return lib.unary_union_prec(collections, grid_size, **kwargs)
# --> 421 return lib.unary_union(collections, **kwargs)
#
# KeyboardInterrupt:

# %%
with open(f"{TEST_NAME}_precision.pkl", 'wb') as f:
    pickle.dump(precisions, f)
with open(f"{TEST_NAME}_recalls.pkl", 'wb') as f:
    pickle.dump(recalls, f)
with open(f"{TEST_NAME}_f1_scores.pkl", 'wb') as f:
    pickle.dump(f1_scores, f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 import pickle
# ----> 2 with open(f"{TEST_NAME}_precision.pkl", 'wb') as f:
#       3     pickle.dump(precisions, f)
#       4 with open(f"{TEST_NAME}_recalls.pkl", 'wb') as f:
#
# NameError: name 'TEST_NAME' is not defined

# %% [markdown]
# # Анализ результатов

# %%
import pickle
with open(f"{TEST_NAME}_precision.pkl", 'rb') as f:
    precisions = pickle.load(f)
with open(f"{TEST_NAME}_recalls.pkl", 'rb') as f:
    recalls = pickle.load(f)
with open(f"{TEST_NAME}_f1_scores.pkl", 'rb') as f:
    f1_scores = pickle.load(f)

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Split each array into two parts
prec1, prec2 = precisions[0], precisions[1]
rec1, rec2 = recalls[0], recalls[1]
f1_1, f1_2 = f1_scores[0], f1_scores[1]

# Create figure with subplots
fig, axes = plt.subplots(3, 2, figsize=(15, 20))

# Plot precision heatmaps
sns.heatmap(prec1, ax=axes[0,0], cmap='viridis', annot=True)
axes[0,0].set_title('Precision Map 1')
sns.heatmap(prec2, ax=axes[0,1], cmap='viridis', annot=True)
axes[0,1].set_title('Precision Map 2')

# Plot recall heatmaps
sns.heatmap(rec1, ax=axes[1,0], cmap='viridis', annot=True)
axes[1,0].set_title('Recall Map 1')
sns.heatmap(rec2, ax=axes[1,1], cmap='viridis', annot=True)
axes[1,1].set_title('Recall Map 2')

# Plot F1 score heatmaps
sns.heatmap(f1_1, ax=axes[2,0], cmap='viridis', annot=True)
axes[2,0].set_title('F1 Score Map 1')
sns.heatmap(f1_2, ax=axes[2,1], cmap='viridis', annot=True)
axes[2,1].set_title('F1 Score Map 2')

plt.tight_layout()
plt.show()

# %%
import pickle
with open(f"dense_precision.pkl", 'rb') as f:
    precisions = pickle.load(f)
with open(f"dense_recalls.pkl", 'rb') as f:
    recalls = pickle.load(f)
with open(f"dense_f1_scores.pkl", 'rb') as f:
    f1_scores = pickle.load(f)

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

x_axes = [round(x, 2) for x in np.linspace(0.3, 0.95, len(f1_scores[0][0]))]
y_axes = np.arange(1, 15)

# Split each array into two parts
prec1, prec2 = precisions[0], precisions[1]
rec1, rec2 = recalls[0], recalls[1]
f1_1, f1_2 = f1_scores[0], f1_scores[1]

# Create figure with subplots
fig, axes = plt.subplots(3, 2, figsize=(15, 20))

# Plot precision heatmaps
sns.heatmap(prec1, ax=axes[0,0], cmap='viridis', annot=True, xticklabels=x_axes, yticklabels=y_axes)
axes[0,0].set_title('Precision Map 1')
sns.heatmap(prec2, ax=axes[0,1], cmap='viridis', annot=True, xticklabels=x_axes, yticklabels=y_axes)
axes[0,1].set_xlabel('Порог фильтрации', fontsize=14)
axes[0,1].set_ylabel('Уровень уверенности сети', fontsize=14)
axes[0,1].set_title('Precision Map 2')

# Plot recall heatmaps
sns.heatmap(rec1, ax=axes[1,0], cmap='viridis', annot=True, xticklabels=x_axes, yticklabels=y_axes)
axes[1,0].set_xlabel('Порог фильтрации', fontsize=14)
axes[1,0].set_ylabel('Уровень уверенности сети', fontsize=14)
axes[1,1].set_title('Recall Map 1')
sns.heatmap(rec2, ax=axes[1,1], cmap='viridis', annot=True, xticklabels=x_axes, yticklabels=y_axes)
axes[1,1].set_xlabel('Порог фильтрации', fontsize=14)
axes[1,1].set_ylabel('Уровень уверенности сети', fontsize=14)
axes[1,1].set_title('Recall Map 2')

# Plot F1 score heatmaps
sns.heatmap(f1_1, ax=axes[2,0], cmap='viridis', annot=True, xticklabels=x_axes, yticklabels=y_axes)
axes[2,0].set_xlabel('Порог фильтрации', fontsize=14)
axes[2,0].set_ylabel('Уровень уверенности сети', fontsize=14)
axes[2,0].set_title('F1 Score Map 1')
sns.heatmap(f1_2, ax=axes[2,1], cmap='viridis', annot=True, xticklabels=x_axes, yticklabels=y_axes)
axes[2,1].set_xlabel('Порог фильтрации', fontsize=14)
axes[2,1].set_ylabel('Уровень уверенности сети', fontsize=14)
axes[2,1].set_title('F1 Score Map 2')

plt.tight_layout()
plt.show()

# %%
import pickle
with open(f"dense_precision.pkl", 'rb') as f:
    precisions = pickle.load(f)
with open(f"dense_recalls.pkl", 'rb') as f:
    recalls = pickle.load(f)
with open(f"dense_f1_scores.pkl", 'rb') as f:
    f1_scores = pickle.load(f)

# %%
from matplotlib import pyplot as plt
import numpy as np
plt.plot(np.linspace(0.3, 0.95, len(f1_scores[0][0])), f1_scores[0][0], label='F1 базовой агрегации')
plt.plot(np.linspace(0.3, 0.95, len(f1_scores[0][0])), [0.82, 0.83, 0.83, 0.84, 0.85, 0.84, 0.84, 0.84, 0.83, 0.83, 0.83, 0.8, 0.75], label='F1 по изображениям')
plt.axvline(0.8, color='red', label='Лучший порог для агрегации', linestyle='--')
plt.axvline(0.5, color='blue', label='Лучший порог по F1 для изображений', linestyle='--')
plt.ylim(0, 1)
plt.xlabel('Порог уверенности сети')
plt.ylabel('F1-score')
plt.title('Зависимость F1-score от порога уверенности сети на плотном тесте')
plt.legend()
