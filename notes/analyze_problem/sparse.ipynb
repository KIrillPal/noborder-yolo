# %%
import sys
sys.path.append('../../utils')
sys.path.append('../..')

from interpolate.markup_utils import load_markup, yolo_dataset_info
from src.metrics import compute_border_metrics, compute_precision_recall, compute_non_border_metrics

# %% [markdown]
# ### Загрузка датасета и модели

# %%
CONFIG_PATH = '../../config.json'
SPLIT = 'test'
IOU_THRESHOLD = 0.7

# %%
# Load config
import json
import numpy as np
from pathlib import Path

with open(CONFIG_PATH, 'r') as f:
    config = json.load(f)

# Load labels
dataset_info = yolo_dataset_info(Path(config['sparse']))
gt_labels_dir = Path(dataset_info[SPLIT]) / 'labels'

# %%
MODEL_VERSION = 'default'

# %%
from ultralytics import YOLO
model = YOLO(config['models'][MODEL_VERSION])

# %% [markdown]
# ### Предсказание с лучшим по F1 confidence

# %%
import subprocess
import shutil
shutil.rmtree('runs/segment', ignore_errors=True)
# Run YOLO validation to get the best confidence score

# Run validation to get best confidence threshold
val_results = model.val(data=config['sparse'], split=SPLIT)

best_f1_idx = np.argmax(val_results.seg.curves_results[1][1].mean(axis=0))
best_f1 = val_results.seg.curves_results[1][1][..., best_f1_idx].mean()
best_conf = val_results.seg.curves_results[1][0][best_f1_idx]
print(f"Best F1: {best_f1:.4f} at confidence {best_conf:.4f}")

# Create temporary directory for predictions
pred_labels_dir = Path('runs/segment/predict/labels')

# Run prediction with best confidence
model.predict(
    source=str(Path(dataset_info[SPLIT]) / 'images'),
    conf=best_conf,
    save_txt=True,
)
# Out:
# Ultralytics 8.3.0 🚀 Python-3.10.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100 80GB PCIe, 81154MiB)
# YOLOv8m-seg summary (fused): 263 layers, 24,586,614 parameters, 0 gradients, 98.7 GFLOPs
# val: Scanning /alpha/projects/wastie/datasets/05_02_sparse_test/test/labels.cache... 210 images, 15 backgrounds, 0 corrupt: 100%|██████████| 210/210 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 14/14 [00:04<00:00,  3.22it/s]
#                    all        210       1085       0.88      0.889      0.945      0.848       0.88      0.889       0.94      0.795
#                    bot        184        723      0.897      0.854      0.933      0.854        0.9      0.857      0.929      0.798
#                   alum        140        362      0.863      0.924      0.957      0.841      0.861      0.922      0.951      0.793
# Speed: 2.1ms preprocess, 6.9ms inference, 0.0ms loss, 1.6ms postprocess per image
# Results saved to runs/segment/val
# Best F1: 0.8854 at confidence 0.5085
#
# image 1/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_00_00_000.jpg: 1024x1024 1 bot, 8.5ms
# image 2/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_00_03_000.jpg: 1024x1024 1 bot, 9.2ms
# image 3/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_00_06_000.jpg: 1024x1024 2 bots, 9.3ms
# image 4/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_00_09_000.jpg: 1024x1024 4 bots, 9.8ms
# image 5/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_00_12_000.jpg: 1024x1024 3 bots, 10.0ms
# image 6/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_00_15_000.jpg: 1024x1024 (no detections), 10.1ms
# image 7/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_00_18_000.jpg: 1024x1024 1 bot, 10.8ms
# image 8/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_00_21_000.jpg: 1024x1024 1 bot, 10.0ms
# image 9/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_00_24_000.jpg: 1024x1024 1 alum, 9.9ms
# image 10/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_00_27_000.jpg: 1024x1024 2 bots, 1 alum, 9.9ms
# image 11/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_00_30_000.jpg: 1024x1024 2 bots, 10.1ms
# image 12/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_00_33_000.jpg: 1024x1024 1 alum, 10.1ms
# image 13/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_00_36_000.jpg: 1024x1024 2 bots, 2 alums, 11.5ms
# image 14/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_00_39_000.jpg: 1024x1024 1 bot, 2 alums, 10.7ms
# image 15/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_00_42_000.jpg: 1024x1024 1 alum, 8.4ms
# image 16/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_00_45_000.jpg: 1024x1024 2 bots, 1 alum, 8.6ms
# image 17/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_00_48_000.jpg: 1024x1024 1 bot, 1 alum, 9.4ms
# image 18/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_00_51_000.jpg: 1024x1024 2 bots, 1 alum, 10.0ms
# image 19/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_00_54_000.jpg: 1024x1024 5 bots, 2 alums, 9.9ms
# image 20/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_00_57_000.jpg: 1024x1024 3 bots, 3 alums, 10.0ms
# image 21/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_01_00_000.jpg: 1024x1024 2 bots, 1 alum, 10.7ms
# image 22/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_01_03_000.jpg: 1024x1024 3 bots, 10.0ms
# image 23/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_01_06_000.jpg: 1024x1024 1 bot, 9.1ms
# image 24/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_01_09_000.jpg: 1024x1024 2 bots, 8.4ms
# image 25/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_01_12_000.jpg: 1024x1024 1 bot, 8.4ms
# image 26/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_01_15_000.jpg: 1024x1024 1 bot, 8.4ms
# image 27/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_01_18_000.jpg: 1024x1024 3 bots, 1 alum, 8.4ms
# image 28/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_01_21_000.jpg: 1024x1024 3 bots, 3 alums, 8.4ms
# image 29/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_01_24_000.jpg: 1024x1024 2 bots, 1 alum, 8.4ms
# image 30/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_01_27_000.jpg: 1024x1024 3 bots, 1 alum, 8.4ms
# image 31/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_01_30_000.jpg: 1024x1024 1 bot, 1 alum, 8.4ms
# image 32/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_01_33_000.jpg: 1024x1024 3 bots, 8.4ms
# image 33/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_01_36_000.jpg: 1024x1024 1 bot, 1 alum, 8.4ms
# image 34/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_01_39_000.jpg: 1024x1024 4 bots, 2 alums, 8.4ms
# image 35/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_01_42_000.jpg: 1024x1024 5 bots, 1 alum, 8.4ms
# image 36/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_01_45_000.jpg: 1024x1024 1 bot, 4 alums, 8.4ms
# image 37/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_01_48_000.jpg: 1024x1024 6 bots, 2 alums, 8.4ms
# image 38/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_01_51_000.jpg: 1024x1024 5 bots, 6 alums, 8.4ms
# image 39/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_01_54_000.jpg: 1024x1024 3 bots, 5 alums, 8.4ms
# image 40/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_01_57_000.jpg: 1024x1024 1 bot, 3 alums, 8.4ms
# image 41/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_02_00_000.jpg: 1024x1024 2 bots, 3 alums, 8.4ms
# image 42/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_02_03_000.jpg: 1024x1024 3 alums, 8.5ms
# image 43/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_02_06_000.jpg: 1024x1024 1 bot, 2 alums, 8.4ms
# image 44/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_02_09_000.jpg: 1024x1024 3 bots, 1 alum, 8.4ms
# image 45/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_02_12_000.jpg: 1024x1024 2 bots, 2 alums, 8.3ms
# image 46/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_02_15_000.jpg: 1024x1024 1 bot, 8.4ms
# image 47/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_02_18_000.jpg: 1024x1024 1 bot, 8.3ms
# image 48/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_02_21_000.jpg: 1024x1024 2 bots, 8.4ms
# image 49/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_02_24_000.jpg: 1024x1024 1 bot, 1 alum, 8.4ms
# image 50/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_02_27_000.jpg: 1024x1024 3 bots, 1 alum, 8.4ms
# image 51/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_02_30_000.jpg: 1024x1024 4 bots, 8.4ms
# image 52/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_02_33_000.jpg: 1024x1024 3 bots, 1 alum, 8.4ms
# image 53/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_02_36_000.jpg: 1024x1024 3 bots, 1 alum, 8.4ms
# image 54/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_02_39_000.jpg: 1024x1024 1 bot, 8.4ms
# image 55/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_02_42_000.jpg: 1024x1024 2 bots, 8.3ms
# image 56/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_02_45_000.jpg: 1024x1024 (no detections), 8.4ms
# image 57/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_02_48_000.jpg: 1024x1024 4 bots, 8.4ms
# image 58/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_02_51_000.jpg: 1024x1024 5 bots, 1 alum, 8.4ms
# image 59/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_02_54_000.jpg: 1024x1024 2 bots, 2 alums, 8.4ms
# image 60/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_02_57_000.jpg: 1024x1024 (no detections), 8.4ms
# image 61/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_03_00_000.jpg: 1024x1024 3 bots, 3 alums, 8.4ms
# image 62/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_03_03_000.jpg: 1024x1024 3 bots, 1 alum, 8.4ms
# image 63/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_03_06_000.jpg: 1024x1024 1 bot, 5 alums, 8.4ms
# image 64/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_03_09_000.jpg: 1024x1024 4 bots, 2 alums, 8.4ms
# image 65/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_03_12_000.jpg: 1024x1024 3 bots, 8.4ms
# image 66/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_03_15_000.jpg: 1024x1024 1 bot, 8.4ms
# image 67/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_03_18_000.jpg: 1024x1024 2 bots, 2 alums, 8.4ms
# image 68/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_03_21_000.jpg: 1024x1024 3 alums, 8.4ms
# image 69/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_03_24_000.jpg: 1024x1024 2 bots, 4 alums, 8.5ms
# image 70/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_03_27_000.jpg: 1024x1024 3 alums, 8.4ms
# image 71/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_03_30_000.jpg: 1024x1024 1 bot, 8.4ms
# image 72/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_03_33_000.jpg: 1024x1024 3 bots, 1 alum, 8.4ms
# image 73/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_03_36_000.jpg: 1024x1024 (no detections), 8.4ms
# image 74/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_03_39_000.jpg: 1024x1024 1 alum, 8.4ms
# image 75/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_03_42_000.jpg: 1024x1024 2 alums, 8.4ms
# image 76/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_03_45_000.jpg: 1024x1024 3 bots, 1 alum, 8.4ms
# image 77/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_03_48_000.jpg: 1024x1024 3 bots, 8.4ms
# image 78/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_03_51_000.jpg: 1024x1024 1 bot, 3 alums, 8.4ms
# image 79/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_03_54_000.jpg: 1024x1024 2 bots, 1 alum, 8.4ms
# image 80/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_03_57_000.jpg: 1024x1024 2 bots, 8.4ms
# image 81/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_04_00_000.jpg: 1024x1024 2 bots, 1 alum, 8.3ms
# image 82/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_04_03_000.jpg: 1024x1024 1 bot, 8.4ms
# image 83/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_04_06_000.jpg: 1024x1024 2 bots, 1 alum, 8.4ms
# image 84/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_04_09_000.jpg: 1024x1024 1 bot, 2 alums, 8.4ms
# image 85/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_04_12_000.jpg: 1024x1024 1 bot, 1 alum, 8.4ms
# image 86/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_04_15_000.jpg: 1024x1024 (no detections), 8.4ms
# image 87/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_04_18_000.jpg: 1024x1024 (no detections), 8.4ms
# image 88/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_04_21_000.jpg: 1024x1024 1 bot, 1 alum, 8.4ms
# image 89/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_04_24_000.jpg: 1024x1024 1 bot, 1 alum, 8.4ms
# image 90/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_04_27_000.jpg: 1024x1024 2 bots, 1 alum, 8.4ms
# image 91/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_04_30_000.jpg: 1024x1024 1 bot, 1 alum, 8.4ms
# image 92/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_04_33_000.jpg: 1024x1024 1 bot, 1 alum, 8.4ms
# image 93/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_04_36_000.jpg: 1024x1024 (no detections), 8.4ms
# image 94/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_04_39_000.jpg: 1024x1024 1 bot, 1 alum, 8.4ms
# image 95/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_04_42_000.jpg: 1024x1024 3 bots, 1 alum, 8.4ms
# image 96/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_04_45_000.jpg: 1024x1024 2 bots, 8.4ms
# image 97/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_04_48_000.jpg: 1024x1024 1 bot, 8.4ms
# image 98/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_04_51_000.jpg: 1024x1024 (no detections), 8.3ms
# image 99/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_04_54_000.jpg: 1024x1024 2 bots, 8.4ms
# image 100/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_04_57_000.jpg: 1024x1024 1 alum, 8.4ms
# image 101/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_05_00_000.jpg: 1024x1024 2 bots, 1 alum, 8.4ms
# image 102/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_05_03_000.jpg: 1024x1024 2 bots, 1 alum, 8.4ms
# image 103/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_05_06_000.jpg: 1024x1024 3 alums, 8.4ms
# image 104/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_05_09_000.jpg: 1024x1024 1 bot, 1 alum, 8.4ms
# image 105/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_05_12_000.jpg: 1024x1024 3 bots, 8.4ms
# image 106/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_05_15_000.jpg: 1024x1024 3 bots, 8.4ms
# image 107/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_05_18_000.jpg: 1024x1024 1 bot, 8.4ms
# image 108/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_05_21_000.jpg: 1024x1024 1 bot, 1 alum, 8.5ms
# image 109/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_05_24_000.jpg: 1024x1024 1 bot, 8.4ms
# image 110/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_05_27_000.jpg: 1024x1024 2 bots, 8.4ms
# image 111/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_05_30_000.jpg: 1024x1024 2 bots, 8.4ms
# image 112/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_05_33_000.jpg: 1024x1024 1 bot, 1 alum, 8.4ms
# image 113/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_05_36_000.jpg: 1024x1024 2 bots, 2 alums, 8.4ms
# image 114/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_05_39_000.jpg: 1024x1024 3 bots, 2 alums, 8.4ms
# image 115/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_05_42_000.jpg: 1024x1024 3 bots, 1 alum, 8.4ms
# image 116/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_05_45_000.jpg: 1024x1024 3 bots, 1 alum, 8.4ms
# image 117/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_05_48_000.jpg: 1024x1024 2 bots, 8.3ms
# image 118/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_05_51_000.jpg: 1024x1024 5 bots, 8.4ms
# image 119/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_05_54_000.jpg: 1024x1024 5 bots, 4 alums, 8.4ms
# image 120/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_05_57_000.jpg: 1024x1024 4 bots, 3 alums, 8.4ms
# image 121/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_06_00_000.jpg: 1024x1024 8 bots, 2 alums, 8.4ms
# image 122/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_06_03_000.jpg: 1024x1024 8 bots, 2 alums, 8.4ms
# image 123/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_06_06_000.jpg: 1024x1024 5 bots, 1 alum, 8.4ms
# image 124/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_06_09_000.jpg: 1024x1024 5 bots, 6 alums, 8.4ms
# image 125/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_06_12_000.jpg: 1024x1024 7 bots, 4 alums, 8.4ms
# image 126/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_06_15_000.jpg: 1024x1024 8 bots, 5 alums, 9.3ms
# image 127/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_06_18_000.jpg: 1024x1024 11 bots, 6 alums, 8.4ms
# image 128/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_06_21_000.jpg: 1024x1024 17 bots, 5 alums, 8.4ms
# image 129/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_06_24_000.jpg: 1024x1024 8 bots, 3 alums, 8.4ms
# image 130/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_06_27_000.jpg: 1024x1024 11 bots, 4 alums, 8.4ms
# image 131/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_06_30_000.jpg: 1024x1024 12 bots, 4 alums, 8.4ms
# image 132/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_06_33_000.jpg: 1024x1024 10 bots, 6 alums, 8.4ms
# image 133/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_06_36_000.jpg: 1024x1024 12 bots, 8 alums, 8.4ms
# image 134/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_06_39_000.jpg: 1024x1024 13 bots, 7 alums, 8.4ms
# image 135/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_06_42_000.jpg: 1024x1024 16 bots, 9 alums, 8.4ms
# image 136/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_06_45_000.jpg: 1024x1024 11 bots, 7 alums, 8.4ms
# image 137/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_06_48_000.jpg: 1024x1024 8 bots, 7 alums, 8.4ms
# image 138/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_06_51_000.jpg: 1024x1024 13 bots, 6 alums, 8.4ms
# image 139/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_06_54_000.jpg: 1024x1024 10 bots, 4 alums, 8.4ms
# image 140/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_06_57_000.jpg: 1024x1024 7 bots, 7 alums, 8.4ms
# image 141/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_07_00_000.jpg: 1024x1024 7 bots, 7 alums, 8.4ms
# image 142/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_07_03_000.jpg: 1024x1024 6 bots, 6 alums, 8.4ms
# image 143/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_07_06_000.jpg: 1024x1024 7 bots, 3 alums, 8.4ms
# image 144/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_07_09_000.jpg: 1024x1024 6 bots, 2 alums, 8.4ms
# image 145/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_07_12_000.jpg: 1024x1024 11 bots, 4 alums, 8.4ms
# image 146/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_07_15_000.jpg: 1024x1024 8 bots, 4 alums, 8.4ms
# image 147/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_07_18_000.jpg: 1024x1024 5 bots, 4 alums, 8.4ms
# image 148/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_07_21_000.jpg: 1024x1024 11 bots, 2 alums, 8.4ms
# image 149/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_07_24_000.jpg: 1024x1024 10 bots, 1 alum, 8.4ms
# image 150/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_07_27_000.jpg: 1024x1024 11 bots, 1 alum, 8.4ms
# image 151/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_07_30_000.jpg: 1024x1024 4 bots, 2 alums, 8.4ms
# image 152/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_07_33_000.jpg: 1024x1024 6 bots, 1 alum, 8.4ms
# image 153/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_07_36_000.jpg: 1024x1024 6 bots, 1 alum, 8.4ms
# image 154/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_07_39_000.jpg: 1024x1024 6 bots, 5 alums, 8.4ms
# image 155/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_07_42_000.jpg: 1024x1024 5 bots, 4 alums, 8.4ms
# image 156/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_07_45_000.jpg: 1024x1024 5 bots, 5 alums, 8.4ms
# image 157/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_07_48_000.jpg: 1024x1024 7 bots, 2 alums, 8.4ms
# image 158/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_07_51_000.jpg: 1024x1024 5 bots, 10 alums, 8.4ms
# image 159/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_07_54_000.jpg: 1024x1024 5 bots, 6 alums, 8.4ms
# image 160/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_07_57_000.jpg: 1024x1024 4 bots, 3 alums, 8.4ms
# image 161/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_08_00_000.jpg: 1024x1024 3 bots, 8.4ms
# image 162/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_08_03_000.jpg: 1024x1024 3 bots, 2 alums, 8.4ms
# image 163/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_08_06_000.jpg: 1024x1024 5 bots, 5 alums, 8.4ms
# image 164/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_08_09_000.jpg: 1024x1024 4 bots, 3 alums, 8.4ms
# image 165/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_08_12_000.jpg: 1024x1024 5 bots, 2 alums, 8.4ms
# image 166/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_08_15_000.jpg: 1024x1024 4 bots, 1 alum, 8.4ms
# image 167/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_08_18_000.jpg: 1024x1024 3 bots, 1 alum, 8.4ms
# image 168/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_08_21_000.jpg: 1024x1024 3 bots, 1 alum, 8.4ms
# image 169/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_08_24_000.jpg: 1024x1024 9 bots, 8.4ms
# image 170/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_08_27_000.jpg: 1024x1024 6 bots, 8.4ms
# image 171/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_08_30_000.jpg: 1024x1024 2 bots, 2 alums, 8.4ms
# image 172/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_08_33_000.jpg: 1024x1024 2 bots, 4 alums, 8.4ms
# image 173/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_08_36_000.jpg: 1024x1024 4 bots, 4 alums, 8.4ms
# image 174/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_08_39_000.jpg: 1024x1024 4 bots, 3 alums, 8.4ms
# image 175/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_08_42_000.jpg: 1024x1024 3 bots, 3 alums, 8.4ms
# image 176/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_08_45_000.jpg: 1024x1024 2 alums, 8.5ms
# image 177/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_08_48_000.jpg: 1024x1024 3 bots, 2 alums, 8.4ms
# image 178/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_08_51_000.jpg: 1024x1024 5 bots, 2 alums, 8.4ms
# image 179/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_08_54_000.jpg: 1024x1024 5 bots, 3 alums, 8.4ms
# image 180/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_08_57_000.jpg: 1024x1024 2 bots, 1 alum, 8.4ms
# image 181/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_09_00_000.jpg: 1024x1024 4 bots, 1 alum, 8.4ms
# image 182/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_09_03_000.jpg: 1024x1024 1 bot, 1 alum, 8.4ms
# image 183/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_09_06_000.jpg: 1024x1024 2 bots, 1 alum, 8.4ms
# image 184/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_09_09_000.jpg: 1024x1024 4 bots, 2 alums, 8.4ms
# image 185/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_09_12_000.jpg: 1024x1024 5 bots, 1 alum, 8.4ms
# image 186/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_09_15_000.jpg: 1024x1024 4 bots, 5 alums, 8.4ms
# image 187/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_09_18_000.jpg: 1024x1024 2 bots, 4 alums, 8.4ms
# image 188/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_09_21_000.jpg: 1024x1024 1 bot, 8.4ms
# image 189/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_09_24_000.jpg: 1024x1024 2 bots, 2 alums, 8.4ms
# image 190/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_09_27_000.jpg: 1024x1024 1 bot, 1 alum, 8.4ms
# image 191/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_09_30_000.jpg: 1024x1024 4 bots, 2 alums, 8.4ms
# image 192/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_09_33_000.jpg: 1024x1024 2 bots, 8.4ms
# image 193/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_09_36_000.jpg: 1024x1024 2 bots, 8.4ms
# image 194/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_09_39_000.jpg: 1024x1024 3 bots, 1 alum, 8.4ms
# image 195/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_09_42_000.jpg: 1024x1024 1 bot, 1 alum, 8.4ms
# image 196/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_09_45_000.jpg: 1024x1024 2 bots, 1 alum, 8.4ms
# image 197/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_09_48_000.jpg: 1024x1024 1 bot, 8.4ms
# image 198/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_09_51_000.jpg: 1024x1024 1 bot, 8.3ms
# image 199/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_09_54_000.jpg: 1024x1024 4 bots, 2 alums, 8.4ms
# image 200/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_09_57_000.jpg: 1024x1024 5 bots, 1 alum, 8.4ms
# image 201/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_10_00_000.jpg: 1024x1024 4 bots, 2 alums, 8.4ms
# image 202/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_10_03_000.jpg: 1024x1024 2 bots, 5 alums, 8.4ms
# image 203/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_10_06_000.jpg: 1024x1024 3 bots, 8.4ms
# image 204/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_10_09_000.jpg: 1024x1024 3 bots, 1 alum, 8.4ms
# image 205/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_10_12_000.jpg: 1024x1024 4 bots, 2 alums, 8.4ms
# image 206/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_10_15_000.jpg: 1024x1024 2 alums, 8.4ms
# image 207/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_10_18_000.jpg: 1024x1024 2 bots, 1 alum, 8.4ms
# image 208/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_10_21_000.jpg: 1024x1024 1 bot, 8.4ms
# image 209/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_10_24_000.jpg: 1024x1024 (no detections), 8.4ms
# image 210/210 /alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_10_27_000.jpg: 1024x1024 1 bot, 8.4ms
# Speed: 5.4ms preprocess, 8.5ms inference, 1.4ms postprocess per image at shape (1, 3, 1024, 1024)
# Results saved to runs/segment/predict
# 201 labels saved to runs/segment/predict/labels
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'bot', 1: 'alum'}
#  obb: None
#  orig_img: array([[[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 3,  3,  3],
#          ...,
#          [20, 18, 18],
#          [20, 18, 18],
#          [20, 18, 18]],
#
#         [[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 3,  3,  3],
#          ...,
#          [22, 19, 19],
#          [22, 19, 19],
#          [22, 19, 19]],
#
#         [[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 3,  3,  3],
#          ...,
#          [20, 20, 20],
#          [19, 22, 20],
#          [19, 22, 20]],
#
#         ...,
#
#         [[ 4,  4,  4],
#          [ 4,  4,  4],
#          [ 4,  4,  4],
#          ...,
#          [17, 16, 13],
#          [15, 17, 10],
#          [13, 19, 16]],
#
#         [[ 4,  4,  4],
#          [ 4,  4,  4],
#          [ 4,  4,  4],
#          ...,
#          [16, 15, 12],
#          [13, 16,  9],
#          [ 9, 15, 11]],
#
#         [[ 4,  4,  4],
#          [ 4,  4,  4],
#          [ 4,  4,  4],
#          ...,
#          [ 6, 12,  9],
#          [ 9, 11, 10],
#          [ 6, 10,  6]]], dtype=uint8)
#  orig_shape: (1000, 1000)
#  path: '/alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_00_00_000.jpg'
#  probs: None
#  save_dir: 'runs/segment/predict'
#  speed: {'preprocess': 6.030559539794922, 'inference': 8.456230163574219, 'postprocess': 3.39508056640625},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'bot', 1: 'alum'}
#  obb: None
#  orig_img: array([[[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 3,  3,  3],
#          ...,
#          [22, 22, 16],
#          [20, 20, 15],
#          [20, 20, 15]],
#
#         [[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 3,  3,  3],
#          ...,
#          [22, 22, 16],
#          [20, 20, 15],
#          [20, 20, 15]],
#
#         [[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 3,  3,  3],
#          ...,
#          [23, 20, 20],
#          [22, 19, 19],
#          [22, 19, 19]],
#
#         ...,
#
#         [[ 4,  4,  4],
#          [ 4,  4,  4],
#          [ 4,  4,  4],
#          ...,
#          [16, 15, 12],
#          [12, 15,  9],
#          [11, 16, 15]],
#
#         [[ 4,  4,  4],
#          [ 4,  4,  4],
#          [ 4,  4,  4],
#          ...,
#          [16, 15, 12],
#          [11, 13,  8],
#          [ 9, 13, 12]],
#
#         [[ 4,  4,  4],
#          [ 4,  4,  4],
#          [ 4,  4,  4],
#          ...,
#          [ 8, 11, 12],
#          [ 9, 12,  9],
#          [ 8, 12,  5]]], dtype=uint8)
#  orig_shape: (1000, 1000)
#  path: '/alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_00_03_000.jpg'
#  probs: None
#  save_dir: 'runs/segment/predict'
#  speed: {'preprocess': 6.065845489501953, 'inference': 9.195089340209961, 'postprocess': 1.7027854919433594},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'bot', 1: 'alum'}
#  obb: None
#  orig_img: array([[[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 3,  3,  3],
#          ...,
#          [23, 18, 18],
#          [23, 18, 18],
#          [23, 18, 18]],
#
#         [[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 3,  3,  3],
#          ...,
#          [24, 19, 19],
#          [24, 19, 19],
#          [24, 19, 19]],
#
#         [[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 3,  3,  3],
#          ...,
#          [20, 20, 20],
#          [20, 20, 20],
#          [20, 20, 20]],
#
#         ...,
#
#         [[ 5,  5,  5],
#          [ 5,  5,  5],
#          [ 5,  5,  5],
#          ...,
#          [16, 15, 12],
#          [11, 12, 10],
#          [12, 16, 17]],
#
#         [[ 5,  5,  5],
#          [ 5,  5,  5],
#          [ 5,  5,  5],
#          ...,
#          [15, 13, 11],
#          [10, 11,  9],
#          [ 9, 12, 13]],
#
#         [[ 5,  5,  5],
#          [ 5,  5,  5],
#          [ 5,  5,  5],
#          ...,
#          [10, 12, 11],
#          [ 8, 10,  9],
#          [11, 13, 12]]], dtype=uint8)
#  orig_shape: (1000, 1000)
#  path: '/alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_00_06_000.jpg'
#  probs: None
#  save_dir: 'runs/segment/predict'
#  speed: {'preprocess': 6.93202018737793, 'inference': 9.346485137939453, 'postprocess': 1.9061565399169922},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'bot', 1: 'alum'}
#  obb: None
#  orig_img: array([[[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 3,  3,  3],
#          ...,
#          [23, 18, 18],
#          [23, 18, 18],
#          [23, 18, 18]],
#
#         [[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 3,  3,  3],
#          ...,
#          [23, 18, 18],
#          [23, 18, 18],
#          [23, 18, 18]],
#
#         [[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 3,  3,  3],
#          ...,
#          [20, 20, 20],
#          [20, 20, 20],
#          [20, 20, 20]],
#
#         ...,
#
#         [[ 4,  4,  4],
#          [ 4,  4,  4],
#          [ 4,  4,  4],
#          ...,
#          [12, 12, 12],
#          [12, 13, 11],
#          [11, 15, 16]],
#
#         [[ 4,  4,  4],
#          [ 4,  4,  4],
#          [ 4,  4,  4],
#          ...,
#          [11, 11, 11],
#          [11, 12, 10],
#          [ 8, 11, 12]],
#
#         [[ 4,  4,  4],
#          [ 4,  4,  4],
#          [ 4,  4,  4],
#          ...,
#          [ 9, 10, 11],
#          [10, 12, 11],
#          [ 9, 11, 10]]], dtype=uint8)
#  orig_shape: (1000, 1000)
#  path: '/alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_00_09_000.jpg'
#  probs: None
#  save_dir: 'runs/segment/predict'
#  speed: {'preprocess': 7.198572158813477, 'inference': 9.834766387939453, 'postprocess': 2.0966529846191406},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'bot', 1: 'alum'}
#  obb: None
#  orig_img: array([[[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 3,  3,  3],
#          ...,
#          [20, 18, 18],
#          [18, 18, 18],
#          [19, 19, 19]],
#
#         [[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 3,  3,  3],
#          ...,
#          [20, 18, 18],
#          [18, 18, 18],
#          [19, 19, 19]],
#
#         [[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 3,  3,  3],
#          ...,
#          [20, 20, 20],
#          [20, 20, 20],
#          [19, 19, 19]],
#
#         ...,
#
#         [[ 5,  5,  5],
#          [ 5,  5,  5],
#          [ 4,  4,  4],
#          ...,
#          [16, 16, 10],
#          [17, 16, 13],
#          [15, 13, 16]],
#
#         [[ 5,  5,  5],
#          [ 5,  5,  5],
#          [ 4,  4,  4],
#          ...,
#          [15, 15,  9],
#          [15, 13, 11],
#          [11, 10, 12]],
#
#         [[ 5,  5,  5],
#          [ 5,  5,  5],
#          [ 4,  4,  4],
#          ...,
#          [11, 10, 12],
#          [10, 10, 10],
#          [12, 10, 10]]], dtype=uint8)
#  orig_shape: (1000, 1000)
#  path: '/alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_00_12_000.jpg'
#  probs: None
#  save_dir: 'runs/segment/predict'
#  speed: {'preprocess': 6.891727447509766, 'inference': 10.02955436706543, 'postprocess': 2.0322799682617188},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'bot', 1: 'alum'}
#  obb: None
#  orig_img: array([[[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 3,  3,  3],
#          ...,
#          [20, 18, 18],
#          [18, 18, 18],
#          [18, 18, 18]],
#
#         [[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 3,  3,  3],
#          ...,
#          [20, 18, 18],
#          [18, 18, 18],
#          [18, 18, 18]],
#
#         [[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 3,  3,  3],
#          ...,
#          [19, 19, 19],
#          [19, 19, 19],
#          [19, 19, 19]],
#
#         ...,
#
#         [[ 4,  4,  4],
#          [ 4,  4,  4],
#          [ 4,  4,  4],
#          ...,
#          [13, 16,  9],
#          [15, 17, 11],
#          [15, 17, 16]],
#
#         [[ 4,  4,  4],
#          [ 4,  4,  4],
#          [ 4,  4,  4],
#          ...,
#          [12, 15,  8],
#          [12, 15,  9],
#          [11, 13, 12]],
#
#         [[ 4,  4,  4],
#          [ 4,  4,  4],
#          [ 4,  4,  4],
#          ...,
#          [10, 12, 11],
#          [ 9, 12,  9],
#          [ 9, 10,  8]]], dtype=uint8)
#  orig_shape: (1000, 1000)
#  path: '/alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_00_15_000.jpg'
#  probs: None
#  save_dir: 'runs/segment/predict'
#  speed: {'preprocess': 7.026910781860352, 'inference': 10.100364685058594, 'postprocess': 0.5555152893066406},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'bot', 1: 'alum'}
#  obb: None
#  orig_img: array([[[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 3,  3,  3],
#          ...,
#          [22, 17, 17],
#          [23, 18, 18],
#          [23, 18, 18]],
#
#         [[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 3,  3,  3],
#          ...,
#          [24, 19, 19],
#          [23, 18, 18],
#          [24, 19, 19]],
#
#         [[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 3,  3,  3],
#          ...,
#          [19, 19, 19],
#          [19, 19, 19],
#          [18, 18, 18]],
#
#         ...,
#
#         [[ 4,  4,  4],
#          [ 4,  4,  4],
#          [ 4,  4,  4],
#          ...,
#          [15, 15, 15],
#          [16, 16, 16],
#          [16, 18, 17]],
#
#         [[ 4,  4,  4],
#          [ 4,  4,  4],
#          [ 4,  4,  4],
#          ...,
#          [13, 13, 13],
#          [15, 15, 15],
#          [13, 16, 15]],
#
#         [[ 4,  4,  4],
#          [ 4,  4,  4],
#          [ 4,  4,  4],
#          ...,
#          [ 9, 11, 10],
#          [ 9, 11, 10],
#          [10, 10, 10]]], dtype=uint8)
#  orig_shape: (1000, 1000)
#  path: '/alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_00_18_000.jpg'
#  probs: None
#  save_dir: 'runs/segment/predict'
#  speed: {'preprocess': 7.039070129394531, 'inference': 10.838985443115234, 'postprocess': 2.0334720611572266},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'bot', 1: 'alum'}
#  obb: None
#  orig_img: array([[[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 3,  3,  3],
#          ...,
#          [23, 18, 18],
#          [23, 18, 18],
#          [23, 18, 18]],
#
#         [[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 3,  3,  3],
#          ...,
#          [24, 19, 19],
#          [24, 19, 19],
#          [24, 19, 19]],
#
#         [[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 3,  3,  3],
#          ...,
#          [19, 19, 19],
#          [19, 19, 19],
#          [19, 19, 19]],
#
#         ...,
#
#         [[ 4,  4,  4],
#          [ 4,  4,  4],
#          [ 4,  4,  4],
#          ...,
#          [13, 15, 12],
#          [15, 16, 13],
#          [13, 17, 13]],
#
#         [[ 4,  4,  4],
#          [ 4,  4,  4],
#          [ 4,  4,  4],
#          ...,
#          [12, 13, 11],
#          [12, 13, 11],
#          [12, 16, 12]],
#
#         [[ 4,  4,  4],
#          [ 4,  4,  4],
#          [ 4,  4,  4],
#          ...,
#          [10, 13, 10],
#          [ 8, 11,  8],
#          [10, 11,  9]]], dtype=uint8)
#  orig_shape: (1000, 1000)
#  path: '/alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_00_21_000.jpg'
#  probs: None
#  save_dir: 'runs/segment/predict'
#  speed: {'preprocess': 7.555723190307617, 'inference': 10.035514831542969, 'postprocess': 1.9369125366210938},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'bot', 1: 'alum'}
#  obb: None
#  orig_img: array([[[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 2,  2,  2],
#          ...,
#          [20, 19, 17],
#          [20, 19, 17],
#          [20, 19, 17]],
#
#         [[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 2,  2,  2],
#          ...,
#          [20, 19, 17],
#          [20, 19, 17],
#          [22, 20, 18]],
#
#         [[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 2,  2,  2],
#          ...,
#          [19, 19, 19],
#          [19, 19, 19],
#          [20, 20, 20]],
#
#         ...,
#
#         [[ 4,  4,  4],
#          [ 4,  4,  4],
#          [ 4,  4,  4],
#          ...,
#          [16, 16, 10],
#          [15, 15,  9],
#          [16, 18, 17]],
#
#         [[ 4,  4,  4],
#          [ 4,  4,  4],
#          [ 4,  4,  4],
#          ...,
#          [15, 15,  9],
#          [13, 13,  8],
#          [12, 15, 13]],
#
#         [[ 4,  4,  4],
#          [ 4,  4,  4],
#          [ 4,  4,  4],
#          ...,
#          [ 9, 11, 10],
#          [ 9, 10,  8],
#          [ 9, 10,  8]]], dtype=uint8)
#  orig_shape: (1000, 1000)
#  path: '/alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_00_24_000.jpg'
#  probs: None
#  save_dir: 'runs/segment/predict'
#  speed: {'preprocess': 7.28917121887207, 'inference': 9.91964340209961, 'postprocess': 2.2306442260742188},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'bot', 1: 'alum'}
#  obb: None
#  orig_img: array([[[ 2,  2,  2],
#          [ 2,  2,  2],
#          [ 3,  3,  3],
#          ...,
#          [20, 19, 17],
#          [20, 19, 17],
#          [20, 19, 17]],
#
#         [[ 2,  2,  2],
#          [ 2,  2,  2],
#          [ 3,  3,  3],
#          ...,
#          [20, 19, 17],
#          [20, 19, 17],
#          [22, 20, 18]],
#
#         [[ 2,  2,  2],
#          [ 2,  2,  2],
#          [ 3,  3,  3],
#          ...,
#          [19, 19, 19],
#          [19, 19, 19],
#          [20, 20, 20]],
#
#         ...,
#
#         [[ 4,  4,  4],
#          [ 4,  4,  4],
#          [ 4,  4,  4],
#          ...,
#          [17, 17, 11],
#          [15, 15,  9],
#          [16, 18, 17]],
#
#         [[ 4,  4,  4],
#          [ 4,  4,  4],
#          [ 4,  4,  4],
#          ...,
#          [16, 16, 10],
#          [13, 13,  8],
#          [12, 15, 13]],
#
#         [[ 4,  4,  4],
#          [ 4,  4,  4],
#          [ 4,  4,  4],
#          ...,
#          [10, 12, 11],
#          [ 9, 10,  8],
#          [ 9, 10,  8]]], dtype=uint8)
#  orig_shape: (1000, 1000)
#  path: '/alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_00_27_000.jpg'
#  probs: None
#  save_dir: 'runs/segment/predict'
#  speed: {'preprocess': 7.58671760559082, 'inference': 9.903192520141602, 'postprocess': 1.943826675415039},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'bot', 1: 'alum'}
#  obb: None
#  orig_img: array([[[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 3,  3,  3],
#          ...,
#          [24, 19, 19],
#          [24, 19, 19],
#          [23, 18, 18]],
#
#         [[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 3,  3,  3],
#          ...,
#          [24, 19, 19],
#          [24, 19, 19],
#          [25, 20, 20]],
#
#         [[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 3,  3,  3],
#          ...,
#          [22, 22, 22],
#          [20, 20, 20],
#          [20, 20, 20]],
#
#         ...,
#
#         [[ 4,  4,  4],
#          [ 4,  4,  4],
#          [ 4,  4,  4],
# ...
#          [ 2,  2,  2],
#          [ 2,  2,  2],
#          ...,
#          [23, 18, 18],
#          [23, 18, 18],
#          [23, 18, 18]],
#
#         [[ 2,  2,  2],
#          [ 2,  2,  2],
#          [ 2,  2,  2],
#          ...,
#          [24, 19, 19],
#          [24, 19, 19],
#          [24, 19, 19]],
#
#         [[ 2,  2,  2],
#          [ 2,  2,  2],
#          [ 2,  2,  2],
#          ...,
#          [20, 20, 20],
#          [20, 20, 20],
#          [20, 20, 20]],
#
#         ...,
#
#         [[ 5,  5,  5],
#          [ 5,  5,  5],
#          [ 4,  4,  4],
#          ...,
#          [15, 16, 13],
#          [15, 17, 10],
#          [18, 23, 16]],
#
#         [[ 5,  5,  5],
#          [ 5,  5,  5],
#          [ 4,  4,  4],
#          ...,
#          [13, 15, 12],
#          [13, 16,  9],
#          [12, 17, 10]],
#
#         [[ 5,  5,  5],
#          [ 5,  5,  5],
#          [ 4,  4,  4],
#          ...,
#          [11, 13, 12],
#          [10, 12, 11],
#          [10, 11,  9]]], dtype=uint8)
#  orig_shape: (1000, 1000)
#  path: '/alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_09_57_000.jpg'
#  probs: None
#  save_dir: 'runs/segment/predict'
#  speed: {'preprocess': 4.9877166748046875, 'inference': 8.377552032470703, 'postprocess': 1.2984275817871094},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'bot', 1: 'alum'}
#  obb: None
#  orig_img: array([[[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 2,  2,  2],
#          ...,
#          [20, 18, 18],
#          [20, 18, 18],
#          [20, 18, 18]],
#
#         [[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 2,  2,  2],
#          ...,
#          [22, 19, 19],
#          [22, 19, 19],
#          [22, 19, 19]],
#
#         [[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 2,  2,  2],
#          ...,
#          [20, 20, 20],
#          [20, 20, 20],
#          [20, 20, 20]],
#
#         ...,
#
#         [[ 5,  5,  5],
#          [ 5,  5,  5],
#          [ 5,  5,  5],
#          ...,
#          [17, 16, 13],
#          [15, 17, 11],
#          [18, 22, 18]],
#
#         [[ 5,  5,  5],
#          [ 5,  5,  5],
#          [ 5,  5,  5],
#          ...,
#          [16, 15, 12],
#          [12, 15,  9],
#          [13, 17, 13]],
#
#         [[ 5,  5,  5],
#          [ 5,  5,  5],
#          [ 5,  5,  5],
#          ...,
#          [ 8, 12, 11],
#          [10, 12, 11],
#          [ 8, 10,  9]]], dtype=uint8)
#  orig_shape: (1000, 1000)
#  path: '/alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_10_00_000.jpg'
#  probs: None
#  save_dir: 'runs/segment/predict'
#  speed: {'preprocess': 5.060672760009766, 'inference': 8.372783660888672, 'postprocess': 1.3437271118164062},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'bot', 1: 'alum'}
#  obb: None
#  orig_img: array([[[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 3,  3,  3],
#          ...,
#          [22, 19, 19],
#          [22, 19, 19],
#          [20, 18, 18]],
#
#         [[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 3,  3,  3],
#          ...,
#          [20, 18, 18],
#          [20, 18, 18],
#          [22, 19, 19]],
#
#         [[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 3,  3,  3],
#          ...,
#          [19, 19, 19],
#          [19, 19, 19],
#          [20, 20, 20]],
#
#         ...,
#
#         [[ 5,  5,  5],
#          [ 5,  5,  5],
#          [ 5,  5,  5],
#          ...,
#          [17, 15, 15],
#          [15, 17, 11],
#          [18, 22, 18]],
#
#         [[ 5,  5,  5],
#          [ 5,  5,  5],
#          [ 5,  5,  5],
#          ...,
#          [16, 13, 13],
#          [13, 16, 10],
#          [12, 16, 12]],
#
#         [[ 5,  5,  5],
#          [ 5,  5,  5],
#          [ 5,  5,  5],
#          ...,
#          [10, 11, 12],
#          [ 9, 11, 10],
#          [ 9, 11, 10]]], dtype=uint8)
#  orig_shape: (1000, 1000)
#  path: '/alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_10_03_000.jpg'
#  probs: None
#  save_dir: 'runs/segment/predict'
#  speed: {'preprocess': 4.883289337158203, 'inference': 8.375406265258789, 'postprocess': 1.3659000396728516},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'bot', 1: 'alum'}
#  obb: None
#  orig_img: array([[[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 3,  3,  3],
#          ...,
#          [24, 19, 19],
#          [24, 19, 19],
#          [24, 19, 19]],
#
#         [[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 3,  3,  3],
#          ...,
#          [24, 19, 19],
#          [24, 19, 19],
#          [24, 19, 19]],
#
#         [[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 3,  3,  3],
#          ...,
#          [19, 19, 19],
#          [19, 19, 19],
#          [19, 19, 19]],
#
#         ...,
#
#         [[ 5,  5,  5],
#          [ 5,  5,  5],
#          [ 5,  5,  5],
#          ...,
#          [16, 16, 16],
#          [13, 16, 10],
#          [15, 18, 15]],
#
#         [[ 5,  5,  5],
#          [ 5,  5,  5],
#          [ 5,  5,  5],
#          ...,
#          [16, 16, 16],
#          [15, 17, 11],
#          [12, 16, 12]],
#
#         [[ 5,  5,  5],
#          [ 5,  5,  5],
#          [ 5,  5,  5],
#          ...,
#          [10, 11, 12],
#          [ 9, 10, 11],
#          [10, 10, 10]]], dtype=uint8)
#  orig_shape: (1000, 1000)
#  path: '/alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_10_06_000.jpg'
#  probs: None
#  save_dir: 'runs/segment/predict'
#  speed: {'preprocess': 4.904985427856445, 'inference': 8.358001708984375, 'postprocess': 1.3287067413330078},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'bot', 1: 'alum'}
#  obb: None
#  orig_img: array([[[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 3,  3,  3],
#          ...,
#          [24, 19, 19],
#          [24, 19, 19],
#          [24, 19, 19]],
#
#         [[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 3,  3,  3],
#          ...,
#          [24, 19, 19],
#          [24, 19, 19],
#          [24, 19, 19]],
#
#         [[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 3,  3,  3],
#          ...,
#          [19, 19, 19],
#          [19, 19, 19],
#          [19, 19, 19]],
#
#         ...,
#
#         [[ 5,  5,  5],
#          [ 5,  5,  5],
#          [ 5,  5,  5],
#          ...,
#          [15, 15, 15],
#          [11, 16,  8],
#          [12, 17, 16]],
#
#         [[ 5,  5,  5],
#          [ 5,  5,  5],
#          [ 5,  5,  5],
#          ...,
#          [12, 12, 12],
#          [10, 15,  6],
#          [10, 15, 13]],
#
#         [[ 5,  5,  5],
#          [ 5,  5,  5],
#          [ 5,  5,  5],
#          ...,
#          [11, 13, 12],
#          [ 8, 11, 12],
#          [ 9, 11, 10]]], dtype=uint8)
#  orig_shape: (1000, 1000)
#  path: '/alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_10_09_000.jpg'
#  probs: None
#  save_dir: 'runs/segment/predict'
#  speed: {'preprocess': 4.789113998413086, 'inference': 8.35871696472168, 'postprocess': 1.3897418975830078},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'bot', 1: 'alum'}
#  obb: None
#  orig_img: array([[[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 3,  3,  3],
#          ...,
#          [19, 19, 19],
#          [19, 19, 19],
#          [19, 19, 19]],
#
#         [[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 3,  3,  3],
#          ...,
#          [19, 19, 19],
#          [19, 19, 19],
#          [19, 19, 19]],
#
#         [[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 3,  3,  3],
#          ...,
#          [20, 20, 20],
#          [20, 20, 20],
#          [20, 20, 20]],
#
#         ...,
#
#         [[ 5,  5,  5],
#          [ 5,  5,  5],
#          [ 5,  5,  5],
#          ...,
#          [13, 18, 11],
#          [16, 20, 13],
#          [17, 19, 18]],
#
#         [[ 5,  5,  5],
#          [ 5,  5,  5],
#          [ 5,  5,  5],
#          ...,
#          [13, 18, 11],
#          [13, 18, 11],
#          [13, 16, 15]],
#
#         [[ 5,  5,  5],
#          [ 5,  5,  5],
#          [ 5,  5,  5],
#          ...,
#          [11, 13, 12],
#          [10, 12, 11],
#          [ 9, 12,  9]]], dtype=uint8)
#  orig_shape: (1000, 1000)
#  path: '/alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_10_12_000.jpg'
#  probs: None
#  save_dir: 'runs/segment/predict'
#  speed: {'preprocess': 4.870891571044922, 'inference': 8.36324691772461, 'postprocess': 1.3344287872314453},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'bot', 1: 'alum'}
#  obb: None
#  orig_img: array([[[ 2,  2,  2],
#          [ 2,  2,  2],
#          [ 2,  2,  2],
#          ...,
#          [20, 18, 18],
#          [20, 18, 18],
#          [22, 19, 19]],
#
#         [[ 2,  2,  2],
#          [ 2,  2,  2],
#          [ 2,  2,  2],
#          ...,
#          [22, 19, 19],
#          [22, 19, 19],
#          [22, 19, 19]],
#
#         [[ 2,  2,  2],
#          [ 2,  2,  2],
#          [ 2,  2,  2],
#          ...,
#          [20, 23, 22],
#          [19, 22, 20],
#          [19, 22, 20]],
#
#         ...,
#
#         [[ 5,  5,  5],
#          [ 5,  5,  5],
#          [ 5,  5,  5],
#          ...,
#          [17, 16, 13],
#          [16, 16, 10],
#          [17, 20, 17]],
#
#         [[ 5,  5,  5],
#          [ 5,  5,  5],
#          [ 5,  5,  5],
#          ...,
#          [16, 15, 12],
#          [15, 15,  9],
#          [13, 17, 13]],
#
#         [[ 5,  5,  5],
#          [ 5,  5,  5],
#          [ 5,  5,  5],
#          ...,
#          [12, 12, 12],
#          [11, 11, 11],
#          [12, 12, 12]]], dtype=uint8)
#  orig_shape: (1000, 1000)
#  path: '/alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_10_15_000.jpg'
#  probs: None
#  save_dir: 'runs/segment/predict'
#  speed: {'preprocess': 5.046367645263672, 'inference': 8.374214172363281, 'postprocess': 1.424551010131836},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'bot', 1: 'alum'}
#  obb: None
#  orig_img: array([[[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 3,  3,  3],
#          ...,
#          [22, 19, 19],
#          [22, 19, 19],
#          [22, 19, 19]],
#
#         [[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 3,  3,  3],
#          ...,
#          [23, 20, 20],
#          [23, 20, 20],
#          [23, 20, 20]],
#
#         [[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 3,  3,  3],
#          ...,
#          [19, 22, 20],
#          [19, 22, 20],
#          [18, 20, 19]],
#
#         ...,
#
#         [[ 4,  4,  4],
#          [ 4,  4,  4],
#          [ 4,  4,  4],
#          ...,
#          [17, 15, 15],
#          [17, 16, 13],
#          [16, 19, 16]],
#
#         [[ 4,  4,  4],
#          [ 4,  4,  4],
#          [ 4,  4,  4],
#          ...,
#          [16, 13, 13],
#          [16, 15, 12],
#          [12, 16, 12]],
#
#         [[ 4,  4,  4],
#          [ 4,  4,  4],
#          [ 4,  4,  4],
#          ...,
#          [12, 11, 13],
#          [12, 11, 13],
#          [13, 13, 13]]], dtype=uint8)
#  orig_shape: (1000, 1000)
#  path: '/alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_10_18_000.jpg'
#  probs: None
#  save_dir: 'runs/segment/predict'
#  speed: {'preprocess': 4.850149154663086, 'inference': 8.363008499145508, 'postprocess': 1.3136863708496094},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'bot', 1: 'alum'}
#  obb: None
#  orig_img: array([[[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 3,  3,  3],
#          ...,
#          [23, 19, 17],
#          [23, 19, 17],
#          [24, 20, 18]],
#
#         [[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 3,  3,  3],
#          ...,
#          [24, 20, 18],
#          [24, 20, 18],
#          [25, 22, 19]],
#
#         [[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 3,  3,  3],
#          ...,
#          [20, 22, 19],
#          [20, 22, 19],
#          [19, 20, 18]],
#
#         ...,
#
#         [[ 5,  5,  5],
#          [ 5,  5,  5],
#          [ 5,  5,  5],
#          ...,
#          [15, 16, 13],
#          [15, 17, 10],
#          [19, 23, 19]],
#
#         [[ 5,  5,  5],
#          [ 5,  5,  5],
#          [ 5,  5,  5],
#          ...,
#          [12, 13, 11],
#          [13, 16,  9],
#          [12, 16, 12]],
#
#         [[ 5,  5,  5],
#          [ 5,  5,  5],
#          [ 5,  5,  5],
#          ...,
#          [11, 12, 13],
#          [12, 13, 15],
#          [12, 12, 12]]], dtype=uint8)
#  orig_shape: (1000, 1000)
#  path: '/alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_10_21_000.jpg'
#  probs: None
#  save_dir: 'runs/segment/predict'
#  speed: {'preprocess': 5.058765411376953, 'inference': 8.363008499145508, 'postprocess': 1.3527870178222656},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'bot', 1: 'alum'}
#  obb: None
#  orig_img: array([[[ 2,  2,  2],
#          [ 2,  2,  2],
#          [ 2,  2,  2],
#          ...,
#          [24, 19, 19],
#          [24, 19, 19],
#          [24, 19, 19]],
#
#         [[ 2,  2,  2],
#          [ 2,  2,  2],
#          [ 2,  2,  2],
#          ...,
#          [25, 20, 20],
#          [25, 20, 20],
#          [24, 19, 19]],
#
#         [[ 2,  2,  2],
#          [ 2,  2,  2],
#          [ 2,  2,  2],
#          ...,
#          [19, 19, 19],
#          [19, 19, 19],
#          [20, 20, 20]],
#
#         ...,
#
#         [[ 5,  5,  5],
#          [ 5,  5,  5],
#          [ 5,  5,  5],
#          ...,
#          [18, 18, 12],
#          [18, 18, 11],
#          [16, 22, 18]],
#
#         [[ 5,  5,  5],
#          [ 5,  5,  5],
#          [ 5,  5,  5],
#          ...,
#          [16, 16, 10],
#          [17, 17, 10],
#          [ 9, 15, 11]],
#
#         [[ 5,  5,  5],
#          [ 5,  5,  5],
#          [ 5,  5,  5],
#          ...,
#          [10, 13, 10],
#          [11, 16,  9],
#          [11, 12, 10]]], dtype=uint8)
#  orig_shape: (1000, 1000)
#  path: '/alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_10_24_000.jpg'
#  probs: None
#  save_dir: 'runs/segment/predict'
#  speed: {'preprocess': 4.868030548095703, 'inference': 8.359670639038086, 'postprocess': 0.3581047058105469},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'bot', 1: 'alum'}
#  obb: None
#  orig_img: array([[[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 3,  3,  3],
#          ...,
#          [24, 19, 19],
#          [24, 19, 19],
#          [24, 19, 19]],
#
#         [[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 3,  3,  3],
#          ...,
#          [24, 19, 19],
#          [24, 19, 19],
#          [24, 19, 19]],
#
#         [[ 3,  3,  3],
#          [ 3,  3,  3],
#          [ 3,  3,  3],
#          ...,
#          [20, 20, 20],
#          [20, 20, 20],
#          [20, 20, 20]],
#
#         ...,
#
#         [[ 4,  4,  4],
#          [ 4,  4,  4],
#          [ 4,  4,  4],
#          ...,
#          [17, 17, 11],
#          [16, 19,  9],
#          [17, 24, 17]],
#
#         [[ 4,  4,  4],
#          [ 4,  4,  4],
#          [ 4,  4,  4],
#          ...,
#          [16, 16, 10],
#          [16, 19,  9],
#          [12, 19, 12]],
#
#         [[ 4,  4,  4],
#          [ 4,  4,  4],
#          [ 4,  4,  4],
#          ...,
#          [11, 11, 11],
#          [10, 12, 11],
#          [12, 16, 12]]], dtype=uint8)
#  orig_shape: (1000, 1000)
#  path: '/alpha/projects/wastie/datasets/05_02_sparse_test/test/images/tula_sep_0002_2024_07_22_18_10_27_000.jpg'
#  probs: None
#  save_dir: 'runs/segment/predict'
#  speed: {'preprocess': 5.047321319580078, 'inference': 8.365392684936523, 'postprocess': 1.367807388305664}]

# %% [markdown]
# ### Подготавливаем данные

# %%
gt_paths = []
pred_paths = []
for gt_path in gt_labels_dir.glob("*.txt"):
    pred_path = pred_labels_dir / gt_path.name
    if not pred_path.exists():
        pred_path.touch()
    gt_paths.append(gt_path)
    pred_paths.append(pred_path)

# %% [markdown]
# ### Считаем метрики

# %%
image_shape = (config['imgsz'], config['imgsz'])

# %%
both_metrics = compute_precision_recall(gt_paths, pred_paths, image_shape, IOU_THRESHOLD)
print(f"Metrics:\nPrecision: {both_metrics['precision']:.4f}\nRecall: {both_metrics['recall']:.4f}")
# Out:
# Masks processed: 100%|██████████| 4/4 [00:00<00:00, 693.62it/s]
# Masks processed: 100%|██████████| 4/4 [00:00<00:00, 371.48it/s]
# Masks processed: 100%|██████████| 14/14 [00:00<00:00, 326.74it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 1587.55it/s]
# Masks processed: 100%|██████████| 7/7 [00:00<00:00, 1035.78it/s]
# Masks processed: 100%|██████████| 4/4 [00:00<00:00, 1106.09it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 907.66it/s]
# Masks processed: 100%|██████████| 6/6 [00:00<00:00, 521.43it/s]
# Masks processed: 100%|██████████| 9/9 [00:00<00:00, 722.49it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 986.90it/s]
# Masks processed: 100%|██████████| 15/15 [00:00<00:00, 804.96it/s]
# Masks processed: 100%|██████████| 11/11 [00:00<00:00, 624.74it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 1048.18it/s]
# Masks processed: 100%|██████████| 11/11 [00:00<00:00, 804.95it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 1470.91it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 828.67it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 1255.40it/s]
# Masks processed: 100%|██████████| 7/7 [00:00<00:00, 360.47it/s]
# Masks processed: 100%|██████████| 7/7 [00:00<00:00, 754.53it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 1173.01it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 1114.17it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 790.48it/s]
# Masks processed: 0it [00:00, ?it/s]
# /alpha/projects/wastie/code/kondrashov/delta/notes/analyze_problem/../../utils/integrate/metrics.py:118: RuntimeWarning: Mean of empty slice.
#   precision = pred_matched.mean()
# /alpha/projects/wastie/code/kondrashov/delta/.venv/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /alpha/projects/wastie/code/kondrashov/delta/notes/analyze_problem/../../utils/integrate/metrics.py:119: RuntimeWarning: Mean of empty slice.
#   recall = gt_matched.mean()
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 1129.73it/s]
# Masks processed: 100%|██████████| 4/4 [00:00<00:00, 1344.65it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 1179.50it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 637.01it/s]
# Masks processed: 100%|██████████| 6/6 [00:00<00:00, 857.79it/s]
# Masks processed: 100%|██████████| 16/16 [00:00<00:00, 473.84it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 834.91it/s]
# Masks processed: 100%|██████████| 4/4 [00:00<00:00, 491.17it/s]
# Masks processed: 100%|██████████| 7/7 [00:00<00:00, 996.10it/s]
# Masks processed: 100%|██████████| 5/5 [00:00<00:00, 352.74it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 1155.46it/s]
# Masks processed: 100%|██████████| 7/7 [00:00<00:00, 746.79it/s]
# Masks processed: 100%|██████████| 4/4 [00:00<00:00, 1399.50it/s]
# Masks processed: 100%|██████████| 8/8 [00:00<00:00, 766.52it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 739.74it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 819.52it/s]
# Masks processed: 100%|██████████| 19/19 [00:00<00:00, 465.97it/s]
# Masks processed: 100%|██████████| 5/5 [00:00<00:00, 1214.54it/s]
# Masks processed: 100%|██████████| 4/4 [00:00<00:00, 524.81it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 987.48it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 972.86it/s]
# Masks processed: 100%|██████████| 9/9 [00:00<00:00, 545.15it/s]
# Masks processed: 100%|██████████| 4/4 [00:00<00:00, 888.44it/s]
# Masks processed: 100%|██████████| 6/6 [00:00<00:00, 1025.25it/s]
# Masks processed: 100%|██████████| 6/6 [00:00<00:00, 478.97it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 1468.08it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 1053.18it/s]
# Masks processed: 100%|██████████| 12/12 [00:00<00:00, 573.85it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 831.21it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 1184.72it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 7/7 [00:00<00:00, 1075.38it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 885.81it/s]
# Masks processed: 100%|██████████| 14/14 [00:00<00:00, 477.43it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 2227.06it/s]
# Masks processed: 100%|██████████| 22/22 [00:00<00:00, 453.10it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 715.26it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 458.82it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 949.94it/s]
# Masks processed: 100%|██████████| 10/10 [00:00<00:00, 972.32it/s]
# Masks processed: 100%|██████████| 9/9 [00:00<00:00, 1000.97it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 1023.38it/s]
# Masks processed: 100%|██████████| 13/13 [00:00<00:00, 404.47it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 19599.55it/s]
# Masks processed: 100%|██████████| 17/17 [00:00<00:00, 470.30it/s]
# Masks processed: 100%|██████████| 4/4 [00:00<00:00, 1212.93it/s]
# Masks processed: 100%|██████████| 6/6 [00:00<00:00, 578.98it/s]
# Masks processed: 100%|██████████| 7/7 [00:00<00:00, 456.49it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 905.51it/s]
# Masks processed: 100%|██████████| 15/15 [00:00<00:00, 639.67it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 1001.86it/s]
# Masks processed: 100%|██████████| 5/5 [00:00<00:00, 995.47it/s]
# Masks processed: 100%|██████████| 11/11 [00:00<00:00, 906.40it/s]
# Masks processed: 100%|██████████| 6/6 [00:00<00:00, 1478.00it/s]
# Masks processed: 100%|██████████| 6/6 [00:00<00:00, 983.77it/s]
# Masks processed: 100%|██████████| 4/4 [00:00<00:00, 1046.68it/s]
# Masks processed: 100%|██████████| 15/15 [00:00<00:00, 204.77it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 2441.39it/s]
# Masks processed: 100%|██████████| 12/12 [00:00<00:00, 451.85it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 21183.35it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 1223.19it/s]
# Masks processed: 100%|██████████| 10/10 [00:00<00:00, 626.53it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 1153.65it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 1015.57it/s]
# Masks processed: 100%|██████████| 4/4 [00:00<00:00, 976.27it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 912.86it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 865.16it/s]
# Masks processed: 100%|██████████| 10/10 [00:00<00:00, 692.55it/s]
# Masks processed: 100%|██████████| 5/5 [00:00<00:00, 1206.23it/s]
# Masks processed: 100%|██████████| 6/6 [00:00<00:00, 933.31it/s]
# Masks processed: 100%|██████████| 6/6 [00:00<00:00, 1537.69it/s]
# Masks processed: 100%|██████████| 4/4 [00:00<00:00, 1157.93it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 978.15it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 985.16it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 799.83it/s]
# Masks processed: 100%|██████████| 5/5 [00:00<00:00, 448.08it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 1309.49it/s]
# Masks processed: 100%|██████████| 9/9 [00:00<00:00, 395.90it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 21732.15it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 23967.45it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 1172.58it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 2534.32it/s]
# Masks processed: 100%|██████████| 4/4 [00:00<00:00, 944.82it/s]
# Masks processed: 100%|██████████| 6/6 [00:00<00:00, 1065.36it/s]
# Masks processed: 100%|██████████| 8/8 [00:00<00:00, 564.19it/s]
# Masks processed: 100%|██████████| 4/4 [00:00<00:00, 712.71it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 686.13it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 2379.07it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 865.52it/s]
# Masks processed: 100%|██████████| 11/11 [00:00<00:00, 431.10it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 1802.19it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 1144.11it/s]
# Masks processed: 100%|██████████| 8/8 [00:00<00:00, 626.30it/s]
# Masks processed: 100%|██████████| 4/4 [00:00<00:00, 1472.98it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 1033.84it/s]
# Masks processed: 100%|██████████| 6/6 [00:00<00:00, 1033.80it/s]
# Masks processed: 100%|██████████| 4/4 [00:00<00:00, 1127.50it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 44384.17it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 1367.34it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 23431.87it/s]
# Masks processed: 100%|██████████| 7/7 [00:00<00:00, 711.50it/s]
# Masks processed: 100%|██████████| 11/11 [00:00<00:00, 1063.02it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 652.25it/s]
# Masks processed: 100%|██████████| 20/20 [00:00<00:00, 420.17it/s]
# Masks processed: 100%|██████████| 6/6 [00:00<00:00, 778.86it/s]
# Masks processed: 100%|██████████| 6/6 [00:00<00:00, 1023.96it/s]
# Masks processed: 100%|██████████| 4/4 [00:00<00:00, 1190.46it/s]
# Masks processed: 100%|██████████| 10/10 [00:00<00:00, 661.34it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 872.99it/s]
# Masks processed: 100%|██████████| 12/12 [00:00<00:00, 581.36it/s]
# Masks processed: 100%|██████████| 7/7 [00:00<00:00, 802.32it/s]
# Masks processed: 100%|██████████| 6/6 [00:00<00:00, 1203.13it/s]
# Masks processed: 100%|██████████| 13/13 [00:00<00:00, 518.26it/s]
# Masks processed: 100%|██████████| 5/5 [00:00<00:00, 819.62it/s]
# Masks processed: 100%|██████████| 4/4 [00:00<00:00, 958.15it/s]
# Masks processed: 100%|██████████| 4/4 [00:00<00:00, 1735.51it/s]
# Masks processed: 100%|██████████| 8/8 [00:00<00:00, 817.92it/s]
# Masks processed: 100%|██████████| 11/11 [00:00<00:00, 802.65it/s]
# Masks processed: 100%|██████████| 11/11 [00:00<00:00, 707.35it/s]
# Masks processed: 100%|██████████| 8/8 [00:00<00:00, 766.36it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 1198.49it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 1134.31it/s]
# Masks processed: 100%|██████████| 4/4 [00:00<00:00, 900.21it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 23831.27it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 1256.16it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 899.58it/s]
# Masks processed: 100%|██████████| 4/4 [00:00<00:00, 1072.23it/s]
# Masks processed: 100%|██████████| 4/4 [00:00<00:00, 913.99it/s]
# Masks processed: 100%|██████████| 9/9 [00:00<00:00, 547.08it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 1368.90it/s]
# Masks processed: 100%|██████████| 9/9 [00:00<00:00, 1059.14it/s]
# Masks processed: 100%|██████████| 6/6 [00:00<00:00, 1309.36it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 2521.37it/s]
# Masks processed: 100%|██████████| 25/25 [00:00<00:00, 371.60it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 1551.53it/s]
# Masks processed: 100%|██████████| 7/7 [00:00<00:00, 499.40it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 1585.45it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 940.01it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 1293.34it/s]
# Masks processed: 100%|██████████| 4/4 [00:00<00:00, 1242.94it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 706.83it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 558.42it/s]
# Masks processed: 100%|██████████| 10/10 [00:00<00:00, 418.34it/s]
# Masks processed: 100%|██████████| 20/20 [00:00<00:00, 395.47it/s]
# Masks processed: 100%|██████████| 18/18 [00:00<00:00, 477.56it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 1070.66it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 699.52it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 1016.80it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 648.20it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 1042.93it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 597.14it/s]
# Masks processed: 100%|██████████| 6/6 [00:00<00:00, 920.85it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 1851.79it/s]
# Masks processed: 100%|██████████| 4/4 [00:00<00:00, 206.90it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 502.25it/s]
# Masks processed: 100%|██████████| 15/15 [00:00<00:00, 360.62it/s]
# Masks processed: 100%|██████████| 6/6 [00:00<00:00, 1432.89it/s]
# Masks processed: 100%|██████████| 4/4 [00:00<00:00, 1858.97it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 1944.51it/s]
# Masks processed: 100%|██████████| 4/4 [00:00<00:00, 1200.17it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 1798.20it/s]
# Masks processed: 100%|██████████| 5/5 [00:00<00:00, 1455.45it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 594.77it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 970.68it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 1070.25it/s]
# Masks processed: 100%|██████████| 4/4 [00:00<00:00, 1589.20it/s]
# Masks processed: 100%|██████████| 14/14 [00:00<00:00, 620.07it/s]
# Masks processed: 100%|██████████| 4/4 [00:00<00:00, 903.94it/s]
# Masks processed: 100%|██████████| 16/16 [00:00<00:00, 446.14it/s]
# Masks processed: 100%|██████████| 6/6 [00:00<00:00, 1020.59it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 3904.10it/s]
# Masks processed: 100%|██████████| 6/6 [00:00<00:00, 1502.08it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 1151.33it/s]
# Masks processed: 100%|██████████| 6/6 [00:00<00:00, 1073.26it/s]
# Masks processed: 100%|██████████| 6/6 [00:00<00:00, 947.54it/s]
# Masks processed: 100%|██████████| 5/5 [00:00<00:00, 1479.58it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 952.28it/s]
# Masks processed: 100%|██████████| 6/6 [00:00<00:00, 1117.19it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 2045.34it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 1168.66it/s]
# Metrics:
# Precision: 0.8721
# Recall: 0.8802

# %%
border_metrics = compute_border_metrics(gt_paths, pred_paths, image_shape, IOU_THRESHOLD)
print(f"Border metrics:\nPrecision: {border_metrics['precision']:.4f}\nRecall: {border_metrics['recall']:.4f}")
# Out:
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 41323.19it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 43690.67it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 1207.69it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 924.47it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 1052.52it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 937.07it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 905.51it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 896.70it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 1096.69it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 1546.57it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 1235.07it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 1689.89it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 1602.10it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 1152.91it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 1257.29it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 23431.87it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 3537.51it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 836.52it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 1254.65it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 1360.46it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 2131.61it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 969.33it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 1585.75it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 1029.78it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 23831.27it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 1223.19it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 755.12it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 1379.71it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 1151.02it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 1407.48it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 1876.23it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 47127.01it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 43919.41it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 1218.04it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 788.50it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 1322.71it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 1001.98it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 1582.16it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 1338.32it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 2232.20it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 25731.93it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 1158.01it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 473.08it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 25266.89it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 2963.47it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 1217.50it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 1447.31it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 1607.94it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 982.96it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 1178.67it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 1699.25it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 24966.10it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 1134.82it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 24672.38it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 1538.07it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 1418.19it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 1371.58it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 976.56it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 509.33it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 1004.38it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 742.88it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 1139.45it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 4/4 [00:00<00:00, 352.25it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 947.01it/s]
# /alpha/projects/wastie/code/kondrashov/delta/notes/analyze_problem/../../utils/integrate/metrics.py:124: RuntimeWarning: invalid value encountered in scalar divide
#   "f1": precision * recall * 2 / (precision + recall),
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 1146.09it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 15420.24it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 408.44it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 420.73it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 546.42it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 333.76it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 420.48it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 682.44it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 9425.40it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 330.78it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 377.08it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 441.88it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 916.39it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 847.79it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 501.98it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 258.93it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 365.44it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 400.89it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 294.54it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 274.48it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 789.07it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 228.73it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 485.38it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 278.20it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 417.34it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 636.18it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 438.73it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 117.65it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 278.51it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 461.96it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 347.34it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 11155.06it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 288.86it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 404.86it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 204.82it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Border metrics:
# Precision: 0.7667
# Recall: 0.7516

# %%
non_border_metrics = compute_non_border_metrics(gt_paths, pred_paths, image_shape, IOU_THRESHOLD)
print(f"Non border metrics:\nPrecision: {non_border_metrics['precision']:.4f}\nRecall: {non_border_metrics['recall']:.4f}")
# Out:
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 424.18it/s]
# Masks processed: 100%|██████████| 4/4 [00:00<00:00, 316.49it/s]
# Masks processed: 100%|██████████| 12/12 [00:00<00:00, 238.91it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 1407.25it/s]
# Masks processed: 100%|██████████| 6/6 [00:00<00:00, 300.20it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 503.82it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 511.56it/s]
# Masks processed: 100%|██████████| 6/6 [00:00<00:00, 341.11it/s]
# Masks processed: 100%|██████████| 8/8 [00:00<00:00, 571.97it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 1037.30it/s]
# Masks processed: 100%|██████████| 12/12 [00:00<00:00, 920.78it/s]
# Masks processed: 100%|██████████| 9/9 [00:00<00:00, 754.42it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 1049.36it/s]
# Masks processed: 100%|██████████| 9/9 [00:00<00:00, 927.15it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 1684.80it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 970.01it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 1352.35it/s]
# Masks processed: 100%|██████████| 7/7 [00:00<00:00, 383.76it/s]
# Masks processed: 100%|██████████| 6/6 [00:00<00:00, 817.39it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 1555.17it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 915.39it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 791.38it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 998.25it/s]
# Masks processed: 100%|██████████| 4/4 [00:00<00:00, 1231.17it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 14074.85it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 598.59it/s]
# Masks processed: 100%|██████████| 5/5 [00:00<00:00, 756.47it/s]
# Masks processed: 100%|██████████| 13/13 [00:00<00:00, 440.56it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 812.53it/s]
# Masks processed: 100%|██████████| 4/4 [00:00<00:00, 630.37it/s]
# Masks processed: 100%|██████████| 6/6 [00:00<00:00, 1148.91it/s]
# Masks processed: 100%|██████████| 5/5 [00:00<00:00, 351.75it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 1192.58it/s]
# Masks processed: 100%|██████████| 7/7 [00:00<00:00, 762.50it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 1534.50it/s]
# Masks processed: 100%|██████████| 5/5 [00:00<00:00, 622.37it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 683.22it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 688.72it/s]
# Masks processed: 100%|██████████| 18/18 [00:00<00:00, 340.17it/s]
# Masks processed: 100%|██████████| 5/5 [00:00<00:00, 1141.25it/s]
# Masks processed: 100%|██████████| 4/4 [00:00<00:00, 379.09it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 579.16it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 428.84it/s]
# Masks processed: 100%|██████████| 9/9 [00:00<00:00, 359.08it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 923.86it/s]
# Masks processed: 100%|██████████| 5/5 [00:00<00:00, 855.70it/s]
# Masks processed: 100%|██████████| 5/5 [00:00<00:00, 453.96it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 1305.62it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 1031.94it/s]
# Masks processed: 100%|██████████| 10/10 [00:00<00:00, 703.47it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 1188.30it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 7/7 [00:00<00:00, 1015.43it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 558.05it/s]
# Masks processed: 100%|██████████| 13/13 [00:00<00:00, 409.41it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 2229.43it/s]
# Masks processed: 100%|██████████| 20/20 [00:00<00:00, 461.00it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 720.05it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 446.25it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 858.26it/s]
# Masks processed: 100%|██████████| 8/8 [00:00<00:00, 721.07it/s]
# Masks processed: 100%|██████████| 7/7 [00:00<00:00, 963.32it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 895.84it/s]
# Masks processed: 100%|██████████| 11/11 [00:00<00:00, 404.99it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 15033.35it/s]
# Masks processed: 100%|██████████| 14/14 [00:00<00:00, 522.72it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 1202.15it/s]
# Masks processed: 100%|██████████| 6/6 [00:00<00:00, 577.94it/s]
# Masks processed: 100%|██████████| 6/6 [00:00<00:00, 547.01it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 745.79it/s]
# Masks processed: 100%|██████████| 14/14 [00:00<00:00, 630.11it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 881.80it/s]
# Masks processed: 100%|██████████| 4/4 [00:00<00:00, 966.88it/s]
# Masks processed: 100%|██████████| 9/9 [00:00<00:00, 884.00it/s]
# Masks processed: 100%|██████████| 5/5 [00:00<00:00, 1152.79it/s]
# Masks processed: 100%|██████████| 5/5 [00:00<00:00, 933.23it/s]
# Masks processed: 100%|██████████| 4/4 [00:00<00:00, 928.92it/s]
# Masks processed: 100%|██████████| 14/14 [00:00<00:00, 206.82it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 2566.11it/s]
# Masks processed: 100%|██████████| 9/9 [00:00<00:00, 404.37it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 24105.20it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 1061.85it/s]
# Masks processed: 100%|██████████| 10/10 [00:00<00:00, 618.05it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 1023.08it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 905.83it/s]
# Masks processed: 100%|██████████| 4/4 [00:00<00:00, 720.33it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 711.38it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 628.08it/s]
# Masks processed: 100%|██████████| 10/10 [00:00<00:00, 600.72it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 1045.70it/s]
# Masks processed: 100%|██████████| 6/6 [00:00<00:00, 906.62it/s]
# Masks processed: 100%|██████████| 4/4 [00:00<00:00, 1672.20it/s]
# Masks processed: 100%|██████████| 4/4 [00:00<00:00, 1093.90it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 843.75it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 902.68it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 597.48it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 256.21it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 1134.67it/s]
# Masks processed: 100%|██████████| 6/6 [00:00<00:00, 345.29it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 25266.89it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 630.06it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 1095.12it/s]
# Masks processed: 100%|██████████| 4/4 [00:00<00:00, 645.75it/s]
# Masks processed: 100%|██████████| 5/5 [00:00<00:00, 813.07it/s]
# Masks processed: 100%|██████████| 6/6 [00:00<00:00, 506.36it/s]
# Masks processed: 100%|██████████| 4/4 [00:00<00:00, 685.76it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 761.91it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 1777.25it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 664.18it/s]
# Masks processed: 100%|██████████| 10/10 [00:00<00:00, 377.96it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 1584.95it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 1055.97it/s]
# Masks processed: 100%|██████████| 6/6 [00:00<00:00, 663.01it/s]
# Masks processed: 100%|██████████| 4/4 [00:00<00:00, 1357.38it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 778.60it/s]
# Masks processed: 100%|██████████| 5/5 [00:00<00:00, 1015.27it/s]
# Masks processed: 100%|██████████| 4/4 [00:00<00:00, 1040.45it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 54471.48it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 1269.27it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 20460.02it/s]
# Masks processed: 100%|██████████| 6/6 [00:00<00:00, 577.40it/s]
# Masks processed: 100%|██████████| 10/10 [00:00<00:00, 941.29it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 586.90it/s]
# Masks processed: 100%|██████████| 16/16 [00:00<00:00, 439.74it/s]
# Masks processed: 100%|██████████| 6/6 [00:00<00:00, 729.87it/s]
# Masks processed: 100%|██████████| 5/5 [00:00<00:00, 1025.05it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 754.24it/s]
# Masks processed: 100%|██████████| 9/9 [00:00<00:00, 614.26it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 776.72it/s]
# Masks processed: 100%|██████████| 11/11 [00:00<00:00, 635.47it/s]
# Masks processed: 100%|██████████| 7/7 [00:00<00:00, 785.66it/s]
# Masks processed: 100%|██████████| 6/6 [00:00<00:00, 1139.96it/s]
# Masks processed: 100%|██████████| 12/12 [00:00<00:00, 522.05it/s]
# Masks processed: 100%|██████████| 4/4 [00:00<00:00, 762.88it/s]
# Masks processed: 100%|██████████| 4/4 [00:00<00:00, 931.50it/s]
# Masks processed: 100%|██████████| 4/4 [00:00<00:00, 1507.12it/s]
# Masks processed: 100%|██████████| 7/7 [00:00<00:00, 805.36it/s]
# Masks processed: 100%|██████████| 11/11 [00:00<00:00, 782.09it/s]
# Masks processed: 100%|██████████| 10/10 [00:00<00:00, 691.55it/s]
# Masks processed: 100%|██████████| 7/7 [00:00<00:00, 717.13it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 1105.02it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 1038.54it/s]
# Masks processed: 100%|██████████| 4/4 [00:00<00:00, 901.37it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 689.51it/s]
# Masks processed: 100%|██████████| 4/4 [00:00<00:00, 863.91it/s]
# Masks processed: 100%|██████████| 4/4 [00:00<00:00, 710.09it/s]
# Masks processed: 100%|██████████| 9/9 [00:00<00:00, 510.83it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 939.58it/s]
# Masks processed: 100%|██████████| 6/6 [00:00<00:00, 1024.50it/s]
# Masks processed: 100%|██████████| 4/4 [00:00<00:00, 1185.17it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 1842.44it/s]
# Masks processed: 100%|██████████| 22/22 [00:00<00:00, 338.98it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 1428.74it/s]
# Masks processed: 100%|██████████| 7/7 [00:00<00:00, 486.04it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 1294.34it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 1118.78it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 1203.99it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 1047.53it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 651.12it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 495.37it/s]
# Masks processed: 100%|██████████| 8/8 [00:00<00:00, 497.71it/s]
# Masks processed: 100%|██████████| 18/18 [00:00<00:00, 415.81it/s]
# Masks processed: 100%|██████████| 16/16 [00:00<00:00, 515.02it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 893.36it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 672.92it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 934.46it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 780.48it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 689.29it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 1205.26it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 572.97it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 1190.10it/s]
# Masks processed: 100%|██████████| 4/4 [00:00<00:00, 372.23it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 707.06it/s]
# Masks processed: 100%|██████████| 12/12 [00:00<00:00, 384.32it/s]
# Masks processed: 100%|██████████| 5/5 [00:00<00:00, 1133.60it/s]
# Masks processed: 100%|██████████| 4/4 [00:00<00:00, 1479.21it/s]
# Masks processed: 0it [00:00, ?it/s]
# Masks processed: 100%|██████████| 4/4 [00:00<00:00, 939.79it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 1022.25it/s]
# Masks processed: 100%|██████████| 5/5 [00:00<00:00, 891.42it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 881.25it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 576.14it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 626.58it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 996.67it/s]
# Masks processed: 100%|██████████| 11/11 [00:00<00:00, 449.99it/s]
# Masks processed: 100%|██████████| 4/4 [00:00<00:00, 832.53it/s]
# Masks processed: 100%|██████████| 14/14 [00:00<00:00, 417.10it/s]
# Masks processed: 100%|██████████| 6/6 [00:00<00:00, 856.91it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 1908.67it/s]
# Masks processed: 100%|██████████| 5/5 [00:00<00:00, 1261.60it/s]
# Masks processed: 100%|██████████| 1/1 [00:00<00:00, 803.04it/s]
# Masks processed: 100%|██████████| 6/6 [00:00<00:00, 716.55it/s]
# Masks processed: 100%|██████████| 6/6 [00:00<00:00, 786.06it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 1263.09it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 868.03it/s]
# Masks processed: 100%|██████████| 5/5 [00:00<00:00, 1362.58it/s]
# Masks processed: 100%|██████████| 3/3 [00:00<00:00, 1482.44it/s]
# Masks processed: 100%|██████████| 2/2 [00:00<00:00, 822.82it/s]
# Non border metrics:
# Precision: 0.8836
# Recall: 0.8959

# %%
# Create a dictionary with all metrics for easy comparison
metrics_comparison = {
    'All objects': both_metrics,
    'Border objects': border_metrics,
    'Non-border objects': non_border_metrics
}

# Print comparison table
print("Metrics comparison:")
print("-" * 60)
print(f"{'Type':<20} {'Precision':>12} {'Recall':>12} {'F1-score':>12}")
print("-" * 60)

for metric_type, metrics in metrics_comparison.items():
    precision = metrics['precision']
    recall = metrics['recall']
    f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
    print(f"{metric_type:<20} {precision:>12.4f} {recall:>12.4f} {f1:>12.4f}")

print("\nAnalysis:")
# Find best performing filter based on F1 score
best_f1 = 0
best_type = None

for metric_type, metrics in metrics_comparison.items():
    precision = metrics['precision']
    recall = metrics['recall']
    f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
    if f1 > best_f1:
        best_f1 = f1
        best_type = metric_type

print(f"The best performing filter is '{best_type}' with F1-score of {best_f1:.4f}")

# Calculate F1 enhancement percentage
baseline = metrics_comparison['All objects']
best_opt = metrics_comparison[best_type]


baseline_f1 = 2 * (baseline['precision'] * baseline['recall']) / (baseline['precision'] + baseline['recall'])
best_f1_score = 2 * (best_opt['precision'] * best_opt['recall']) / (best_opt['precision'] + best_opt['recall'])

f1_enhancement = ((best_f1_score - baseline_f1) / baseline_f1) * 100
print(f"\nF1 score enhancement: {f1_enhancement:.2f}%")
print(f"Recall enhancement:    {(best_opt['recall'] - baseline['recall']) / baseline['recall'] * 100:.2f}%")
print(f"Precision enhancement: {(best_opt['precision'] - baseline['precision']) / baseline['precision'] * 100:.2f}%")
# Calculate error reduction coefficient
error_reduction = (1 - baseline_f1) / (1 - best_f1_score)
print(f"\nError reduction coefficient: {error_reduction:.3f}x ({(error_reduction - 1)*100:.1f}%)")
# Out:
# Metrics comparison:
# ------------------------------------------------------------
# Type                    Precision       Recall     F1-score
# ------------------------------------------------------------
# All objects                0.8721       0.8802       0.8761
# Border objects             0.7667       0.7516       0.7591
# Non-border objects         0.8836       0.8959       0.8897
#
# Analysis:
# The best performing filter is 'Non-border objects' with F1-score of 0.8897
#
# F1 score enhancement: 1.55%
# Recall enhancement:    1.79%
# Precision enhancement: 1.31%
#
# Error reduction coefficient: 1.123x (12.3%)

# %%
print("The main result:")
f1_b = 2 * (metrics_comparison['Border objects']['precision'] * metrics_comparison['Border objects']['recall']) / (metrics_comparison['Border objects']['precision'] + metrics_comparison['Border objects']['recall'])
f1_n = 2 * (metrics_comparison['Non-border objects']['precision'] * metrics_comparison['Non-border objects']['recall']) / (metrics_comparison['Non-border objects']['precision'] + metrics_comparison['Non-border objects']['recall'])
main_error_coeff = (1-f1_b) / (1-f1_n)
print(f"\nError coefficient between Border and Non-Border masks: {main_error_coeff:.3f}x ({(main_error_coeff - 1)*100:.1f}%)")
# Out:
# The main result:
#
# Error coefficient between Border and Non-Border masks: 2.185x (118.5%)

# %% [markdown]
# ### Статистическая значимость результата

# %%
import numpy as np
import pandas as pd
from statsmodels.stats.contingency_tables import mcnemar

def mcnemar_test(sample1, sample2, exact : bool = False):
    """
    Вычисляет критерий Макнимары для двух бинарных выборок.

    Параметры:
    ----------
    sample1 : list, numpy array или pandas Series
        Первая бинарная выборка (0 и 1).
    sample2 : list, numpy array или pandas Series
        Вторая бинарная выборка (0 и 1).
    exact : bool
        Флаг для использования хи-квадрат без аппроксимации. 
        Подходит для маленьких выборок. По умолчанию False.

    Возвращает:
    -----------
    stat : float
        Значение статистики критерия Макнимары.
    p_value : float
        p-value для проверки гипотезы.
    """
    # Проверка, что выборки имеют одинаковую длину
    if len(sample1) != len(sample2):
        raise ValueError("Выборки должны иметь одинаковую длину.")

    # Создание таблицы сопряженности 2x2
    table = pd.crosstab(sample1, sample2)

    # Проверка, что таблица 2x2
    if table.shape != (2, 2):
        raise ValueError("Таблица сопряженности должна быть 2x2.")

    # Вычисление критерия Макнимары
    result = mcnemar(table, exact=exact)
    stat = result.statistic
    p_value = result.pvalue

    return stat, p_value

# %% [markdown]
# ##### Подготовим данные

# %%
b_conf = np.array(border_metrics['conf_matrix'], dtype=np.int32)
nb_conf = np.array(non_border_metrics['conf_matrix'], dtype=np.int32)
is_border = {}
is_matched = {}
for bc, nbc, title in [(b_conf, nb_conf, 'GT'), (b_conf.T, nb_conf.T, 'Pred')]:
    border_cnt = bc[:, 0].sum()
    non_border_cnt = nbc[:, 0].sum()
    part_is_border = [0] * non_border_cnt + [1] * border_cnt
    part_is_matched = [0] * nbc[1, 0] + [1] * nbc[0, 0]
    part_is_matched += [0] * bc[1, 0] + [1] * bc[0, 0]
    
    is_border[title] = part_is_border
    is_matched[title] = part_is_matched

# %% [markdown]
# ##### 1. Проверим корреляцию между флагом, что объект краевой, и флагом, что объект верно предсказан

# %%
total_is_border = is_border['GT'] + is_border['Pred']
total_is_matched = is_matched['GT'] + is_matched['Pred']
is_border['Total'] = total_is_border
is_matched['Total'] = total_is_matched

print("| Sample | Correlation coefficient | Sample size |")
print("|--------|-------------------------|-------------|")
print(f"| Total  | {np.corrcoef(total_is_border, total_is_matched)[0, 1]:>23.6f} | {len(total_is_border):>11} |")
print(f"| GT     | {np.corrcoef(is_border['GT'], is_matched['GT'])[0, 1]:>23.6f} | {len(is_border['GT']):>11} |")
print(f"| Pred   | {np.corrcoef(is_border['Pred'], is_matched['Pred'])[0, 1]:>23.6f} | {len(is_border['Pred']):>11} |")
# Out:
# | Sample | Correlation coefficient | Sample size |
# |--------|-------------------------|-------------|
# | Total  |               -0.135076 |        2180 |
# | GT     |               -0.152145 |        1085 |
# | Pred   |               -0.118617 |        1095 |

# %% [markdown]
# ##### 2. Посмотрим на корреляцию Спирмена, чтобы оценить статистическую значимость зависимости.

# %%
from scipy.stats import spearmanr

print("| Sample | Spearman correlation | p-value               |")
print("|--------|----------------------|-----------------------|")
for sample in ['GT', 'Pred', 'Total']:
    corr, p_value = spearmanr(is_border[sample], is_matched[sample])
    print(f"| {sample:>6} | {corr:>20.6f} | {p_value:>21} |")
# Out:
# | Sample | Spearman correlation | p-value               |
# |--------|----------------------|-----------------------|
# |     GT |            -0.152145 | 4.775586809830902e-07 |
# |   Pred |            -0.118617 | 8.335695840007079e-05 |
# |  Total |            -0.135076 | 2.416828256792319e-10 |

# %% [markdown]
# Таким образом, на уровне значимости $\alpha=0.05$
# 1) зависимость крайне значима для предсказанных масок. Отвергаем гипотезу для Pred.
# 2) незначима для GT масок, поэтому мы не можем отвергнуть гипотезу независимости GT.

# %% [markdown]
# ##### 3. Применим Хи-квадрат для проверки независимости верного предсказания у краевых и некраевых объектов

# %%
from scipy.stats import chi2_contingency

for bc, nbc, title in [(b_conf, nb_conf, 'GT'), (b_conf.T, nb_conf.T, 'Pred')]:
    edge_objects = [0] * bc[1, 0] + [1] * bc[0, 0]
    non_edge_objects = [0] * nbc[1, 0] + [1] * nbc[0, 0]

    # Построение таблицы сопряженности
    # Строки: краевые и некраевые объекты
    # Столбцы: верное и неверное предсказание
    table = np.array([
        [sum(edge_objects), len(edge_objects) - sum(edge_objects)],  # Краевые объекты: верно, неверно
        [sum(non_edge_objects), len(non_edge_objects) - sum(non_edge_objects)]  # Некраевые объекты: верно, неверно
    ])

    # Применение критерия хи-квадрат
    chi2_stat, p_value, dof, expected = chi2_contingency(table)

    # Вывод p-value
    print(f"p-value критерия хи-квадрат ({title}): {p_value}")
# Out:
# p-value критерия хи-квадрат (GT): 1.0640154219134213e-06
# p-value критерия хи-квадрат (Pred): 0.000147364302709179

# %% [markdown]
# Получили аналогичный результат

# %% [markdown]
# ### Вывод

# %% [markdown]
# Между полученными метриками, корреляциями, критерием Спирмена и $\Chi^2$ нет противоречий.

# %% [markdown]
# - Критерии Спирмена и $\Chi^2$ сошлись во мнении о характере связи между краевым свойством и предсказанием масок для обоих групп.
# - При не обнаруженной значимой связи между краевым свойством и предсказанием GT масок, разница recall для краевых и некраевых масок незначительна. Однако при значительной связи для Pred масок, мы видим худшую точность предсказания краевых масок, чем некраевых. Таким образом, результаты критериев согласуются с метриками.
# - Корреляция между флагами, высокая для Pred и низкая для GT, согласуется с критериями. Согласно корреляции, существует обратная зависимость между флагом того, что предсказанный объект краевой, и флагом того, что объект предсказан верно. Это согласуется с метриками, где удаление краевых объектов приводит к улучшению точности.

# %% [markdown]
# Предлагается отмести краевые объекты как вносящие статистически значимый шум в предсказание.
#
# В первом приближении, возможны следующие варианты:
#
# 1) Игнорировать вывод всех краевых объектов, предсказанных сетью.
# 2) Удалить краевые объекты из GT, тем самым мотивировав сеть отказаться от пресказания объектов на границах.
